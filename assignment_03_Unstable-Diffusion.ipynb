# %% [markdown]
# # Group Project / Assignment 3: Retrieval-Augmented Generation Question Answering
# **Assignment due 6 April 11:59pm 2025**
#
# Welcome to the third assignment for 50.055 Machine Learning Operations.
# The third and fourth assignment together form the course group project. You will be working in your project groups to build a chatbot which can answer questions about SUTD to prospective students.
#
#
# **This assignment is a group assignment.**
#
# - Read the instructions in this notebook carefully
# - Add your solution code and answers in the appropriate places. The questions are marked as **QUESTION:**, the places where you need to add your code and text answers are marked as **ADD YOUR SOLUTION HERE**
# - The completed notebook, including your added code and generated output will be your submission for the assignment.
# - The notebook should execute without errors from start to finish when you select "Restart Kernel and Run All Cells..". Please test this before submission.
# - Use the SUTD Education Cluster to solve and test the assignment. If you work on another environment, minimally test your work on the SUTD Education Cluster.
#
# **Rubric for assessment**
#
# Your submission will be graded using the following criteria.
# 1. Code executes: your code should execute without errors. The SUTD Education cluster should be used to ensure the same execution environment.
# 2. Correctness: the code should produce the correct result or the text answer should state the factual correct answer.
# 3. Style: your code should be written in a way that is clean and efficient. Your text answers should be relevant, concise and easy to understand.
# 4. Partial marks will be awarded for partially correct solutions.
# 5. Creativity and innovation: in this assignment you have more freedom to design your solution, compared to the first assignments. You can show of your creativity and innovative mindset.
# 6. There is a maximum of 225 points for this assignment.
#
# **ChatGPT policy**
#
# If you use AI tools, such as ChatGPT, to solve the assignment questions, you need to be transparent about its use and mark AI-generated content as such. In particular, you should include the following in addition to your final answer:
# - A copy or screenshot of the prompt you used
# - The name of the AI model
# - The AI generated output
# - An explanation why the answer is correct or what you had to change to arrive at the correct answer
#
# **Assignment Notes:** Please make sure to save the notebook as you go along. Submission instructions are located at the bottom of the notebook.

# %% [markdown]
# ### Retrieval-Augmented Generation (RAG)
#
# In this assignment, you will be building a Retrieval-Augmented Generation (RAG) question answering system which can answer questions about SUTD.
#
# We'll be leveraging `langchain` and `llama 3.2`.
#
# Check out the docs:
# - [LangChain](https://docs.langchain.com/docs/)
# - [Llama 3.2](https://www.llama.com/docs/model-cards-and-prompt-formats/llama3_2/)
#
#
# The SUTD website used to allow chatting with current students. Unfortunately, this feature does not exist anymore. Let's build a chatbot to fill this gap!

# %% [markdown]
# ### Conduct user research
#
# What are the questions that prospective and current students have about SUTD? In week 2, you already conducted some user research to understand your users.

# %% [markdown]
# ### Value Proposition Canvas
#
#
# ### QUESTION:
#
# Paste the value proposition canvas which you have created in week 2 into this notebook below.
#
#
# **--- ADD YOUR SOLUTION HERE (10 points) ---**
#
# - (replace canvas image below)
#
# ------------------------------

# %% [markdown]
# ![VPC.png](VPC.png)

# %% [markdown]
# # Install dependencies
# Use pip to install all required dependencies of this assignment in the cell below. Make sure to test this on the SUTD cluster as different environments have different software pre-installed.

# %%
# QUESTION: Install and import all required packages
# The rest of your code should execute without any import or dependency errors.

# **--- ADD YOUR SOLUTION HERE (10 points) ---**
# !pip install unstructured langchain pdfminer.six pi_heif unstructured-inference pdf2image tesseract pymupdf sentence-transformers faiss-cpu accelerate rank-bm25 nltk langchain-community
import os
import requests
from urllib.parse import urljoin, urlparse, quote
from collections import deque
import hashlib
import tqdm
import time
from bs4 import BeautifulSoup
from langchain.document_loaders import UnstructuredHTMLLoader, UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain.llms import HuggingFacePipeline
from langchain.chains import RetrievalQA
from langchain.schema import Document, BaseRetriever
from huggingface_hub import login
import torch
import fitz
from rank_bm25 import BM25Okapi
from nltk.tokenize import word_tokenize
import re
from typing import Any, List
# ----------------

# %% [markdown]
# # Download documents
# The RAG application should be able to answer questions based on ingested documents. For the SUTD chatbot, download PDF and HTML files from the SUTD website. The documents should contain information about the admission process, available courses and the university in general.

# %%
# QUESTION: Download documents from the SUTD website
# You should download at least 10 documents but more documents can increase the knowledge base of your chatbot.

# **--- ADD YOUR SOLUTION HERE (20 points) ---**
# Creating a safe filename to download
def create_filename(url, extension=".html"):
    safe_url = quote(url, safe=":/")
    safe_url = safe_url.replace("https://", "").replace("http://", "")
    safe_url = safe_url.replace("/", "_").replace(":", "_")
    return f"{safe_url}{extension}"

# Checking the validity of the URL
def is_valid(url, base_netloc):
    parsed = urlparse(url)
    return bool(parsed.netloc) and (parsed.netloc.endswith(base_netloc) or base_netloc in parsed.netloc)

# Download PDF
def download_pdf(pdf_url, output_folder):
    try:
        response = requests.get(pdf_url)
        if response.status_code == 200:
            filename = create_filename(pdf_url, extension=".pdf")
            file_path = os.path.join(output_folder, filename)
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f"Saved PDF: {filename}")
    except Exception as e:
        print(f"Error saving {pdf_url}: {e}")

# Find the next page
def find_next_page(soup):
    next_page = None
    for link in soup.find_all('a', href=True):
        if 'next' in link.get_text().lower():
            next_page = link['href']
            break
    return next_page

# Main crawling function
def crawl(url, base_netloc, visited, output_folder, depth=0, max_depth=2):
    if url in visited or depth > max_depth:
        return
    visited.add(url)
    
    try:
        response = requests.get(url)
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        return
    
    content_type = response.headers.get('Content-Type', '')
    
    if 'application/pdf' in content_type:
        download_pdf(url, output_folder)
        return

    if 'text/html' not in content_type:
        return
    
    filename = create_filename(url, extension=".html")
    file_path = os.path.join(output_folder, filename)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(response.text)
    print(f"Saved webpage: {filename}")
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    next_page = find_next_page(soup)
    if next_page:
        next_url = urljoin(url, next_page)
        if is_valid(next_url, base_netloc):
            crawl(next_url, base_netloc, visited, output_folder, depth + 1, max_depth)

    for link in soup.find_all('a', href=True):
        next_url = urljoin(url, link['href'])
        if is_valid(next_url, base_netloc):
            crawl(next_url, base_netloc, visited, output_folder, depth + 1, max_depth)

output_folder = 'downloaded_docs'
os.makedirs(output_folder, exist_ok=True)

# URLs to crawl
urls_to_crawl = [
    "https://www.sutd.edu.sg/admissions",
    "https://www.sutd.edu.sg/admissions/undergraduate/",
    "https://www.sutd.edu.sg/admissions/graduate/masters/",
    "https://www.sutd.edu.sg/admissions/graduate/phd/",
    "https://www.sutd.edu.sg/admissions/academy",
    "https://www.42singapore.sg/admissions/",
    "https://www.sutd.edu.sg/innovation/",
    "https://www.sutd.edu.sg/education/accreditation",
    "https://www.sutd.edu.sg/research/research-programmes-fellowships",
    "https://www.sutd.edu.sg/innovation/educational-technology",
    "https://www.sutd.edu.sg/innovation/fabrication-lab",
    "https://www.sutd.edu.sg/campus-life",
    "https://www.sutd.edu.sg/about/happenings",
    "https://www.sutd.edu.sg/about/at-a-glance",
    "https://www.sutd.edu.sg/about/diversity-inclusion/building-gender-diversity/",
    "https://www.sutd.edu.sg/education/undergraduate/academic-calendar/overview/ay2024-onwards/",
    "https://www.sutd.edu.sg/education/undergraduate/academic-calendar/term-dates/2025-2/#tabs",
    "https://www.sutd.edu.sg/campus-life/student-life",
    "https://www.sutd.edu.sg/campus-life/academic-facilities/",
    "https://www.sutd.edu.sg/campus-life/housing/",
    "https://www.sutd.edu.sg/campus-life/sports-and-recreation-centre/",
    "https://www.sutd.edu.sg/campus-life/fnb-and-services/dining",
    "https://www.sutd.edu.sg/education/undergraduate/courses",
    "https://www.sutd.edu.sg/asd/",
    "https://www.sutd.edu.sg/dai/",
    "https://www.sutd.edu.sg/epd/",
    "https://www.sutd.edu.sg/esd/",
    "https://www.sutd.edu.sg/istd/",
    "https://www.sutd.edu.sg/smt/",
    "https://www.sutd.edu.sg/hass/"
    "https://www.sutd.edu.sg/education/undergraduate/majors",
    "https://www.sutd.edu.sg/education/undergraduate/minors",
]

visited = set()
for start_url in urls_to_crawl:
    base_netloc = urlparse(start_url).netloc
    crawl(start_url, base_netloc, visited, output_folder, depth=0, max_depth=3)
# Out:
# Saved webpage: www.sutd.edu.sg_admissions.html
# Saved webpage: www.sutd.edu.sg_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_.html
# Saved webpage: www.sutd.edu.sg_about_people_faculty.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd.html
# Saved webpage: www.sutd.edu.sg_resources.html
# Saved webpage: www.sutd.edu.sg_education.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_masters_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_.html
# Saved webpage: www.sutd.edu.sg_education_accreditation.html
# Saved webpage: www.sutd.edu.sg_education_cyber-physical-learning-alliance_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_asd.html
# Saved webpage: www.sutd.edu.sg_dai.html
# Saved webpage: www.sutd.edu.sg_epd.html
# Saved webpage: www.sutd.edu.sg_esd.html
# Saved webpage: www.sutd.edu.sg_hass.html
# Saved webpage: www.sutd.edu.sg_istd.html
# Saved webpage: www.sutd.edu.sg_smt.html
# Saved webpage: www.sutd.edu.sg_research.html
# Saved webpage: www.sutd.edu.sg_research_research-news_.html
# Saved webpage: www.sutd.edu.sg_research_research-centres.html
# Saved webpage: www.sutd.edu.sg_research_research-programmes-fellowships.html
# Saved webpage: www.sutd.edu.sg_research_research-integrity.html
# Saved webpage: www.sutd.edu.sg_research_institutional-review-board_.html
# Saved webpage: www.sutd.edu.sg_innovation.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology.html
# Saved webpage: www.sutd.edu.sg_innovation_fabrication-lab.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_.html
# Saved webpage: www.sutd.edu.sg_enterprise.html
# Saved webpage: www.sutd.edu.sg_enterprise_research-collaborations.html
# Saved webpage: www.sutd.edu.sg_enterprise_technology-licensing.html
# Saved webpage: www.sutd.edu.sg_enterprise_design-innovation_.html
# Saved webpage: www.sutd.edu.sg_research_research-centres_designz_.html
# Saved webpage: www.sutd.edu.sg_enterprise_venture-innovation-entrepreneurship.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate.html
# Saved webpage: www.sutd.edu.sg_admissions_academy.html
# Saved webpage: www.sutd.edu.sg_campus-life.html
# Saved webpage: www.sutd.edu.sg_campus-life_undergraduate-opportunities-programme_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life.html
# Saved webpage: www.sutd.edu.sg_campus-life_global-experience-and-exchange_.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_.html
# Saved webpage: www.sutd.edu.sg_campus-life_wellbeing-services_.html
# Saved webpage: www.sutd.edu.sg_campus-life_academic-facilities_.html
# Saved webpage: www.sutd.edu.sg_campus-life_housing_.html
# Saved webpage: www.sutd.edu.sg_campus-life_sports-and-recreation-centre_.html
# Saved webpage: www.sutd.edu.sg_campus-life_fnb-and-services_dining.html
# Saved webpage: www.sutd.edu.sg_about.html
# Saved webpage: www.sutd.edu.sg_about_design-ai_.html
# Saved webpage: www.sutd.edu.sg_about_at-a-glance.html
# Saved webpage: www.sutd.edu.sg_about_diversity-inclusion.html
# Saved webpage: www.sutd.edu.sg_about_sustainability.html
# Saved webpage: www.sutd.edu.sg_about_people_leadership.html
# Saved webpage: www.sutd.edu.sg_about_people_board-of-trustees.html
# Saved webpage: www.sutd.edu.sg_about_people_president-emeritus.html
# Saved webpage: www.sutd.edu.sg_about_people_professorships_.html
# Saved webpage: www.sutd.edu.sg_about_happenings.html
# Saved webpage: www.sutd.edu.sg_about_careers.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_term-dates_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview_ay2024-onwards_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview_ay2020-to-ay2023_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview_before-ay2020_%23tabs.html
# Saved webpage: www.sutd.edu.sg_campus-life_undergraduate-opportunities-programme_upop_.html
# Saved webpage: www.sutd.edu.sg_campus-life_global-experience-and-exchange_student-exchange_outbound_global-exchange-programme-gexp_.html
# Saved webpage: www.sutd.edu.sg_campus-life_global-experience-and-exchange_student-exchange_outbound_singapore-universities-student-exchange-programme_.html
# Saved webpage: www.sutd.edu.sg_contact-us_get-in-touch_.html
# Saved webpage: www.sutd.edu.sg_contact-us_getting-around-sutd_.html
# Saved webpage: www.sutd.edu.sg_contact-us_contact-sutd_.html
# Saved webpage: www.sutd.edu.sg_whistleblowing-policy_.html
# Saved webpage: www.sutd.edu.sg_terms-and-conditions_.html
# Saved webpage: www.sutd.edu.sg_privacy-statement_.html
# Saved webpage: www.sutd.edu.sg_design-powered-by-ai_.html
# Saved webpage: www.sutd.edu.sg_airxeed-radiosonde_.html
# Saved webpage: www.sutd.edu.sg_mustango-dall-e-for-music_.html
# Saved webpage: www.sutd.edu.sg_Admissions_Undergraduate.html
# Saved webpage: www.sutd.edu.sg_Admissions.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_application-guide_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_appeal_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_admission-requirements_overview.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_immersion_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_education-expenses_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_scholarship_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_early-matriculation_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_integrated-learning-programme_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_other-financing-options_cpf-education-loan-scheme_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_other-financing-options_moe-tuition-fee-loan_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_other-financing-options_moe-study-loan-scheme_.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_12_SUTD_SL_Application_Procedures.pdf.pdf
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_%3Fpost_tag%3D1656.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_ask-admissions_.html
# Saved webpage: www.sutd.edu.sg_Admissions_Graduate.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_masters%23tabs.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_phd_%23tabs.html
# Saved webpage: www.sutd.edu.sg_Admissions_Graduate%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_programme-listing_master-of-science-in-technology-and-design_application_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-sustainable-urban-design_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-architectural-design-computation_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-ai-and-technology-in-education_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_master-of-science-in-design-and-artificial-intelligence-for-enterprise_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_master-of-architecture-programme_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mssd_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_master-of-engineering-research_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mneed_.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_masters_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_scholarship.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_edb-ipp_.html
# Saved webpage: www.sutd.edu.sg_campus-life_housing_graduate-housing_.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_mailing-list_.html
# Saved webpage: www.sutd.edu.sg_Admissions_Academy.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_courses-and-modules_.html
# Saved webpage: www.sutd.edu.sg_course_generative-ai-for-design_.html
# Saved webpage: www.sutd.edu.sg_course_certified-generative-ai-in-project-management_.html
# Saved webpage: www.sutd.edu.sg_course_certified-generative-ai-professional_.html
# Saved webpage: www.sutd.edu.sg_course_certified-scrum-product-owner_.html
# Saved webpage: www.sutd.edu.sg_course_certified-scrum-master_.html
# Saved webpage: www.sutd.edu.sg_course_certified-prompt-engineering_.html
# Saved webpage: www.sutd.edu.sg_course_strategic-design-ai-and-technology-integration-for-executives_.html
# Saved webpage: www.sutd.edu.sg_course_sctp-gradcert-in-fundamentals-in-data-science_.html
# Saved webpage: www.sutd.edu.sg_course_foundation-of-data-science_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_sctp-programmes_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_professional-certificate_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_modular-master_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_corporate-training_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_executive-programme_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_faq_%3Fpost_tag%3D1785.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_mailing-list_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-organisations-fifth-row_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-awards_honours-list_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-awards_student-achievement-awards_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-awards_student-academic-awards_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_part-time-work-scheme_.html
# Saved webpage: www.sutd.edu.sg_Campus-Life_Housing.html
# Saved webpage: www.sutd.edu.sg_Campus-Life_Housing_Freshmore-Terms-1-2.html
# Saved webpage: www.sutd.edu.sg_campus-life_housing_undergraduate-housing_.html
# Saved webpage: www.sutd.edu.sg_Campus-Life_Housing_Non-graduating.html
# Saved webpage: www.sutd.edu.sg_Campus-Life_Housing_Staff.html
# Saved webpage: www.sutd.edu.sg_Campus-Life_Housing_Visitor.html
# Saved webpage: www.sutd.edu.sg_campus-life_housing_off-campus-accommodation_.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry_recruitment-opportunities_.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry_%23tabs.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry_recruitment-opportunities_%23tabs.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry_gems-career-portal_%23tabs.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_industry_collaborative-projects_%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_.html
# Saved webpage: www.sutd.edu.sg_campus-life_career-development_faq_%3Fpost_tag%3D808%26faq-category%3D810%252C811.html
# Saved webpage: www.sutd.edu.sg_contact-us_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_giving_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_giving_giving-opportunities_avenues-for-giving_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_giving_giving-opportunities_how-to-give_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_giving_ambassadors-circle_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_giving_contact-us_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_a-living-organism-design-for-the-end-of-the-world_.html
# Saved webpage: www.sutd.edu.sg_admissions_.html
# Saved webpage: www.sutd.edu.sg_about_people_faculty_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_overview_ay2024-onwards_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_.html
# Saved webpage: www.sutd.edu.sg_asd_education.html
# Saved webpage: www.sutd.edu.sg_asd_education_undergraduate_curriculum_.html
# Saved webpage: www.sutd.edu.sg_asd_education_undergraduate_courses_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-phd-programme_.html
# Saved webpage: www.sutd.edu.sg_asd_education_career-prospects_.html
# Saved webpage: www.sutd.edu.sg_asd_education_faq_.html
# Saved webpage: www.sutd.edu.sg_asd_projects.html
# Saved webpage: www.sutd.edu.sg_asd_publications.html
# Saved webpage: www.sutd.edu.sg_asd_people_advisory-board_.html
# Saved webpage: www.sutd.edu.sg_asd_people_faculty_.html
# Saved webpage: www.sutd.edu.sg_asd_people_researchers_.html
# Saved webpage: www.sutd.edu.sg_asd_people_students_.html
# Saved webpage: www.sutd.edu.sg_asd_people_staff_.html
# Saved webpage: www.sutd.edu.sg_asd_about.html
# Saved webpage: www.sutd.edu.sg_asd_about_news.html
# Saved webpage: www.sutd.edu.sg_asd_about_events.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights.html
# Saved webpage: www.sutd.edu.sg_asd_about_architects-studio-talk_.html
# Saved webpage: www.sutd.edu.sg_asd_about_sutdio_.html
# Saved webpage: www.sutd.edu.sg_asd_about_overseas-trips.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-awards_student-academic-awards_asd_.html
# Saved webpage: www.sutd.edu.sg_campus-life_student-life_student-awards_honours-list_asd_.html
# Saved webpage: www.sutd.edu.sg_asd_about_giving.html
# Saved webpage: www.sutd.edu.sg_asd_about_academic-facilities_.html
# Saved webpage: www.sutd.edu.sg_about_careers_.html
# Saved webpage: www.sutd.edu.sg_repo_course_20-512-thesis_.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%3Fyears%3D2020.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%3Fproject_type%3Dcore.html
# Saved webpage: www.sutd.edu.sg_asd_contact-us_.html
# Saved webpage: www.sutd.edu.sg_events-listing_inspirecon-2025_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D22.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D44.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D99.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D11.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D867.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D697.html
# Saved webpage: www.sutd.edu.sg_events-listing_cantonese-opera-sound-and-colour_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2025%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D56%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D865%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D697%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-coil-seminar-by-allan-jie-improving-reasoning-capabilities-in-large-language-models-techniques-and-experiences_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D11%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_digital-communications-networks-2024-best-paper-awards_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_moe-acrf-tier-2-august-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_llm-agents-mooc-hackathon-2025_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_national-first-place-in-accenture-university-innovation-challenge-2025-team-halen_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_google-south-asia-southeast-asia-research-awards-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-professor-tony-quek-and-his-co-authors-for-being-awarded-two-best-paper-awards-at-ieee-globecom-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-professor-tony-quek-and-his-co-authors-for-winning-the-ieee-icsidp-2024-best-paper-award_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-student-lucas-toh-and-his-team-for-winning-3rd-place-overall-and-1st-place-for-cohere-challenge_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-assistant-professor-wang-bo-for-winning-db-globalchip-award-at-the-isocc-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_sutd-faculty-recognised-globally-for-exceptional-research-in-clarivates-highly-cited-researchers-2024_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements_%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements_%3Fpaged%3D24%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events.html
# Saved webpage: www.sutd.edu.sg_about_happenings_news_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_pressroom.html
# Saved webpage: www.sutd.edu.sg_news-listing_a-simple-thank-you-thats-all-i-need-says-artist-who-surprises-strangers-with-portraits_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_news%3Fyears%3D2025.html
# Saved webpage: www.sutd.edu.sg_about_happenings_news%3Fpillar-cluster%3D22.html
# Saved webpage: www.sutd.edu.sg_news-listing_whats-a-bus-shelter-doing-in-a-dementia-ward-in-singapore_.html
# Saved webpage: www.sutd.edu.sg_news-listing_sutd-student-wins-singapore-valley-award-for-ai-software-aimed-at-reducing-teacher-workload_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_phd_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_course-schedule-2024-25_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_criteria-for-admission_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_application_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_financing_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_financing_scholarship_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_financing_tuition-fees_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-engineering-doctorate_financing_billing-and-payment-modes_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_epd-phd-programme_courses_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_esd-phd-programme_courses_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mssd_course-catalogue_%23tabs.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_phd_%3Fprogramme-type%3D764.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_phd_%3Fprogramme-level%3D770.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-nus-joint-phd-programme_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-nus-joint-phd-programme_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-nus-joint-phd-programme_application_%23tabs.html
# Saved webpage: www.sutd.edu.sg_programme-listing_sutd-nus-joint-phd-programme_criteria-for-admission_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_people_faculty_full-time_.html
# Saved webpage: www.sutd.edu.sg_dai_people_faculty.html
# Saved webpage: www.sutd.edu.sg_epd_people_faculty_full-time_.html
# Saved webpage: www.sutd.edu.sg_esd_people_faculty_full-time-faculty_.html
# Saved webpage: www.sutd.edu.sg_hass_people_faculty_.html
# Saved webpage: www.sutd.edu.sg_istd_people_faculty_full-time_.html
# Saved webpage: www.sutd.edu.sg_smt_people_faculty_.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_scholarship_.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_scholarship_sutd-graduate-fellowships-scholarships_%23tabs.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_scholarship_sutd-managed-scholarships_%23tabs.html
# Saved webpage: www.sutd.edu.sg_admissions_graduate_scholarship_external-fellowships-scholarships_%23tabs.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_11_SUTDSupplierOnboardingGuide.pdf%23page%3D10.pdf
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_suppliers_supplier-registration_.html
# Saved webpage: www.sutd.edu.sg_about_partnering-with-sutd_suppliers.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_11_SUTDSupplierOnboardingGuide.pdf%23page%3D8.pdf
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_11_SUTDSupplierOnboardingGuide.pdf%23page%3D17.pdf
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_11_SUTDSupplierOnboardingGuide.pdf%23page%3D28.pdf
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_12_SUTDSupplierOnboardingGuide.pdf.pdf
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_%23popup-sidebar-content.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2025_01_OSA_SFA_UGSLApplForm_1.pdf.pdf
# Saved PDF: www.sutd.edu.sg_repo_wp-content_uploads_sites_2_2025_01_SUTD-Doc-CheckList_SL.pdf.pdf
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_%3Fpaged%3D2%23faq-listing.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_%3Fpaged%3D3%23faq-listing.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_faq_%3Fpaged%3D10%23faq-listing.html
# Saved webpage: www.sutd.edu.sg_innovation_.html
# Saved webpage: www.sutd.edu.sg_news-listing_partner-ai-create-wellness-tourism-experience.html
# Saved webpage: www.sutd.edu.sg_about_happenings_news%3Fyears%3D2024.html
# Saved webpage: www.sutd.edu.sg_about_happenings_news%3Fpillar-cluster%3D1167.html
# Saved webpage: www.sutd.edu.sg_innovation_campusx.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_academic-media-studio_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_workshops_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_policies_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_about-us_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_online-exam_.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_plagiarism-tool_.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_vdimension_.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_subject-and-instructor-evaluation_.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_academic-media-studio.html
# Saved webpage: www.sutd.edu.sg_innovation_educational-technology_learning-solutions-and-applications_teaching-and-learning-equipment_.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_programme_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_run-3_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_past-runs_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_news_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_partners_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_contact_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_past-runs_run-2_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_past-runs_run-1-2024_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_steamunity_programme_.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_signature-programmes_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_mentorship-programmes_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_other-events-initiatives_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2023_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2022_%23tabs.html
# Saved webpage: www.42singapore.sg_admissions_.html
# Saved webpage: www.42singapore.sg_admissions_%23main.html
# Saved webpage: www.42singapore.sg_.html
# Saved webpage: www.42singapore.sg_%23main.html
# Saved webpage: www.42singapore.sg_about-us_.html
# Saved webpage: www.42singapore.sg_curriculum_.html
# Saved webpage: www.42singapore.sg_the-piscine_.html
# Saved webpage: www.42singapore.sg_faq_.html
# Saved webpage: www.42singapore.sg_contact-us_.html
# Saved webpage: www.42singapore.sg_contact-us_%23Location.html
# Saved webpage: www.42singapore.sg_press-release_.html
# Saved webpage: www.42singapore.sg_media-gallery_.html
# Saved webpage: www.42singapore.sg_sponsor_.html
# Saved webpage: www.sutd.edu.sg_about_diversity-inclusion_building-gender-diversity_.html
# Saved webpage: www.sutd.edu.sg_about_diversity-inclusion_building-gender-diversity_%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_diversity-inclusion_special-education-needs-support_%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_diversity-inclusion_special-education-needs-support_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_financial-aid_study-bursary-awards_iwa-gyan-jyoti-study-award_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_financing-options-and-aid_financial-aid_study-bursary-awards.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_scholarship_sutd-administered_kewalram-chanrai-group-scholarship-for-women-sc_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_scholarship_sutd-administered.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_scholarship_sutd-administered_paypal-sutd-women-luminaries-programme_.html
# Saved webpage: www.sutd.edu.sg_admissions_undergraduate_scholarship_sutd-administered_singtel-sutd-women-in-tech-scholarship_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_term-dates_2025-2_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_term-dates_2025-2_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_academic-calendar_term-dates.html
# Saved webpage: www.sutd.edu.sg_asd_.html
# Saved webpage: www.sutd.edu.sg_asd_projects_.html
# Saved webpage: www.sutd.edu.sg_asd_asd_projects.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_.html
# Saved webpage: www.sutd.edu.sg_asd_projects_faculty_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_forest-edge-architecture-and-sustainable-design-asd_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_localizing-metro-nature-architecture-and-sustainable-design-asd_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_the-heart-of-ghim-moh-architecture-and-sustainable-design-asd_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_urban-tributaries-architecture-and-sustainable-design-asd_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_architecture-core-studio-3-architecture-and-sustainable-design-asd_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_neighbourhood-animal-farm_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_gradshow-3-metadata-2_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_gradshow-4-makerspace-2_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_gradshow-5-metropolis-2_.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_gradshow-6-multiplicity_.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%3Fpaged%3D2%23project-listing.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%3Fpaged%3D3%23project-listing.html
# Saved webpage: www.sutd.edu.sg_asd_projects_student_%3Fpaged%3D6%23project-listing.html
# Saved webpage: www.sutd.edu.sg_asd_projects_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_architecture-science-and-technology_.html
# Saved webpage: www.sutd.edu.sg_course_20-201-architecture-science-technology.html
# Saved webpage: www.sutd.edu.sg_profile_daniel-joseph-whittaker_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fpillar-cluster%3D1167.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fcourse-term%3D858.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fcourse-type%3D852.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_architecture-science-and-technology_%23media-tile-lightbox-1.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_architecture-science-and-technology_%23media-tile-lightbox-2.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_sites_2_2025_01_asd-20201-ast-term4-2019-pdf_26a937.pdf.pdf
# Saved webpage: www.sutd.edu.sg_achievements-listing_future-of-us-pavilion-has-clinched-the-2020-ida-design-award-bronze-in-the-professional-category-of-architecture.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fyears%3D2021.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fyears%3D2021%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-prof-xiong-zehui-in-winning-ieee-computer-society-ieee-cs-early-career-researcher-award-for-excellence-in-scalable-computing-information-systems-technology-and-design-istd_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-asd-alumni-ian-soon-on-winning-directors-choice-the-warming-competition-2021_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-asd-alumni-tan-gee-yang-on-winning-3rd-prize-in-fentress-global-challenge-2021_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_sutd-wins-innovation-prize-at-the-purmundus-challenge-2021_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_elevation-to-ieee-fellow_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-student-tan-nguyen-long-for-winning-best-innovation-award-and-for-third-place-for-asia-pacific-exchange-in-the-innoserve-awards-2021-information-systems-technology-and-design-ist_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-phd-student-garbelini-matheus-eduardo-for-winning-the-intel-bug-bounty-award-information-systems-technology-and-design-istd_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_microtas-2021-palm-springs_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-assistant-professor-soujanya-poria-for-best-paper-award-honorable-mention-at-icmi-2021-information-systems-technology-and-design-istd_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_congratulations-to-associate-professor-cai-kui-who-made-it-to-the-singapore-top-100-women-in-technology-2021-listing_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fyears%3D2021%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fyears%3D2021%26paged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fyears%3D2021%26paged%3D5%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fpillar-cluster%3D1167.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fpillar-cluster%3D1167%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_blooming-flower-hanabii-pacifier-wins-2024-kyoto-global-design-award_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_ai-sampling-singapore-project-blt-built-design-awards-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_world-cities-summit-young-leaders-2024_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_project-management-institute-singapore-chapter-student-competition-2023_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_julius-baer-x-tenity-intrapreneurship-program-2023_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_sea-games-2023_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_singapore-university-games-sunig-2022_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_accenture-university-innovation-challenge-2023_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_inter-collegiate-cup-icc-march-2023_.html
# Saved webpage: www.sutd.edu.sg_achievements-listing_youth-action-challenge-season-4-oct-2022-feb-2023_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fpillar-cluster%3D1167%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fpillar-cluster%3D1167%26paged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_achievements%3Fpillar-cluster%3D1167%26paged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_digital-biomimetics_.html
# Saved webpage: www.sutd.edu.sg_course_20-316-digital-biomimetics-sustainable-materials-and-manufacturing_.html
# Saved webpage: www.sutd.edu.sg_course_20-212-digital-design-and-fabrication_.html
# Saved webpage: www.sutd.edu.sg_course_30-001-structures-materials_.html
# Saved webpage: www.sutd.edu.sg_course_30-007-engineering-design-innovation_.html
# Saved webpage: www.sutd.edu.sg_profile_stylianos-dritsas_.html
# Saved webpage: www.sutd.edu.sg_profile_javier-g-fernandez_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fcourse-type%3D853.html
# Saved webpage: www.sutd.edu.sg_asd_course-publication_digital-biomimetics_%23media-tile-lightbox-1.html
# Saved PDF: www.sutd.edu.sg_repo_wp-content_uploads_sites_2_2025_01_asd-20316-db-term6-2020-pdf.pdf.pdf
# Saved webpage: www.sutd.edu.sg_asd_about_events_.html
# Saved webpage: www.sutd.edu.sg_asd_asd_about.html
# Saved webpage: www.sutd.edu.sg_asd_about_events_%3Fperiod%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_events_%3Fperiod%3Dupcoming.html
# Saved webpage: www.sutd.edu.sg_asd_about_events_%3Fperiod%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_events_%3Fperiod%3Dupcoming%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_events-listing_inspirecon-2025_.html
# Saved webpage: www.sutd.edu.sg_asd_about_events_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_events-listing_master-of-architecture-information-session-for-intake-2025_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-coil-seminar-by-chen-kin-siong-generative-ai-cybersecurity-preparing-for-the-next-wave-of-attacks_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-coil-seminar-by-wong-choon-bong-introduction-to-the-cyber-security-agency-of-singapore_.html
# Saved webpage: www.sutd.edu.sg_events-listing_watch-out-for-safety-threatening-actors-mitigating-risk-zbigniew-kalbarczyk_.html
# Saved webpage: www.sutd.edu.sg_events-listing_design-for-growth-liu-hanmo_.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-coil-seminar-by-zachary-teo-functional-programming-with-clojure-in-the-wild_.html
# Saved webpage: www.sutd.edu.sg_events-listing_network-optimization-platform-pricing-coupled-energy-transportation-ding-yanyan_.html
# Saved webpage: www.sutd.edu.sg_events-listing_theatre-in-the-city-the-role-of-the-arts-in-urban-communities-by-cheng-nien-yuan-from-singapore-university-of-technology-and-design_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast%26paged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fyears%3D2024%26period%3Dpast%26paged%3D37%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_pressroom_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fperiod%3Dpast%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fperiod%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_events-listing_master-of-architecture-information-session-for-intake-2025_.html
# Saved webpage: www.sutd.edu.sg_events-listing_asd-gradshow-9-oh_.html
# Saved webpage: www.sutd.edu.sg_events-listing_condensations-singapore-international-water-week-2024_.html
# Saved webpage: www.sutd.edu.sg_events-listing_master-of-architecture-information-session-for-intake-2024_.html
# Saved webpage: www.sutd.edu.sg_events-listing_archifuture-design-challenge-2023_.html
# Saved webpage: www.sutd.edu.sg_events-listing_master-of-architecture-lecture-series-2022-design-beyond-zero_.html
# Saved webpage: www.sutd.edu.sg_events-listing_asst-prof-michael-budigs-future-hybrid-high-rise-commune-project-is-on-display-at-the-17th-venice-biennale-international-architecture-exhibition_.html
# Saved webpage: www.sutd.edu.sg_events-listing_asst-prof-immanuel-koh-is-appointed-chair-assistant-professor-of-the-hokkien-foundation-career-professorship_.html
# Saved webpage: www.sutd.edu.sg_events-listing_asd-joins-the-asia-pacific-architecture-festival-2021-with-seminars-podcast-and-an-online-showcase_.html
# Saved webpage: www.sutd.edu.sg_events-listing_prof-carlos-banon-features-in-designsingapore-6th-episode-of-designspottingsg_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fpillar-cluster%3D1167%26period%3Dpast%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D870%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_events-listing_congratulations-to-associate-professor-desmond-lokes-lab-for-receiving-the-2024-techconnect-innovation-award_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D870%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D870%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D870%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_events-listing_pasquinelli-2023-the-eye-of-the-master-conclusion-chapter_.html
# Saved webpage: www.sutd.edu.sg_events-listing_congratulations-to-associate-professor-liu-xiaogangs-phd-student-in-winning-the-royal-society-of-chemistry-rsc-excellent-student-award-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_events-listing_congratulations-to-assistant-professor-ang-yee-sin-for-receiving-the-young-scientist-award_.html
# Saved webpage: www.sutd.edu.sg_events-listing_dr-lee-chee-huei-and-dr-ching-chee-leong-featured-on-berita-harian_.html
# Saved webpage: www.sutd.edu.sg_events-listing_dr-pang-yang-hueis-presentation-with-the-academy-of-singapore-teachers_.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-pillar-sharing-and-industry-engagement-day_.html
# Saved webpage: www.sutd.edu.sg_events-listing_tech-sampler-a-little-bit-about-everything_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D870%26period%3Dpast%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_events-listing_guided-cooperation-for-multi-agent-teams-pamela-wang_.html
# Saved webpage: www.sutd.edu.sg_events-listing_extracting-reasoning-with-structured-information-natural-language-beyond-chia-yew-ken_.html
# Saved webpage: www.sutd.edu.sg_events-listing_domain-aware-stealthy-attack-digital-twin-based-defence-cii-wei-lin_.html
# Saved webpage: www.sutd.edu.sg_events-listing_hcd-automated-labelling-interventions-mitigate-misinformation-social-media-gionnieve-lim_.html
# Saved webpage: www.sutd.edu.sg_events-listing_behaviour-analysis-complex-environments-ng-xun-long_.html
# Saved webpage: www.sutd.edu.sg_events-listing_ai-metrics-performance-safety-trustworthiness-bhardwaj-rishabh_.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-phd-oral-defense-seminar-by-zhu-lanyun-towards-data-efficient-and-continual-semantic-segmentation_.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-phd-oral-defense-seminar-by-dai-siyang-urban-intelligence-machine-learning-for-human-and-environmental_.html
# Saved webpage: www.sutd.edu.sg_events-listing_itai-arad-centre-of-quantum-computation-tensor-networks-and-the-belief-propagation-algorithm_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast%26paged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast%26paged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D873%26period%3Dpast%26paged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D872%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D872%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D872%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-level%3D872%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_events-listing_asd-gradshow-9-oh_.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D867%26period%3Dpast.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D867%26period%3Dupcoming%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D867%26period%3Dpast%23tabs.html
# Saved webpage: www.sutd.edu.sg_about_happenings_events_%3Fevent-category%3D867%26period%3Dpast%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_events-listing_sutd-world-of-design-ai_.html
# Saved webpage: www.sutd.edu.sg_events-listing_50-047-mobile-robotics-course-autonomous-race-car-challenge_.html
# Saved webpage: www.sutd.edu.sg_events-listing_2023-esd-dba-project-showcase_.html
# Saved webpage: www.sutd.edu.sg_events-listing_istd-design-exhibition-2023_.html
# Saved webpage: www.sutd.edu.sg_asd_about_news_.html
# Saved webpage: www.sutd.edu.sg_asd_about_news_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_who-bears-the-heat-of-climate-change-helping-communities-deal-with-rising-temperatures_.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_turning-vacant-houses-into-investments-a-young-architects-journey-to-japan_.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_partner-ai-create-wellness-tourism-experience_.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_singhealth-mou-universities-population-health_.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_studied-architecture-before-medicine-medical-student-explores-the-connection-between-the-two_.html
# Saved webpage: www.sutd.edu.sg_asd_about_news_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_asd_about_news_%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_asd_about_news_%3Fpaged%3D18%23general-listing.html
# Saved webpage: www.sutd.edu.sg_asd_news-listing_award-winning-architect-who-led-pinnacleduxton-project-to-join-sutd-as-full-time-professor_.html
# Saved webpage: www.sutd.edu.sg_singapore.html
# Saved webpage: www.sutd.edu.sg_singapore_design-duo-behind-hdb-s-gamechanging-pinnacleduxton.html
# Saved webpage: www.sutd.edu.sg_singapore_st-s-communities-in-the-sky-project-wins-best-news-website-sph-media-is-top-winner-with-8-awards.html
# Saved webpage: www.sutd.edu.sg_tags_sutdsingapore-university-of-technology-and-design%3Fref%3Darticle-bottom.html
# Saved webpage: www.sutd.edu.sg_tags_architecture%3Fref%3Darticle-bottom.html
# Saved webpage: www.sutd.edu.sg_tags_tertiary-education%3Fref%3Darticle-bottom.html
# Saved webpage: www.sutd.edu.sg_rewards.html
# Saved webpage: www.sutd.edu.sg_rewards-tnc.html
# Saved webpage: www.sutd.edu.sg_faq-rewards.html
# Saved webpage: www.sutd.edu.sg_newsletter-signup.html
# Saved webpage: www.sutd.edu.sg_RSS-Feeds.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_.html
# Saved webpage: www.sutd.edu.sg_asd_asd_about_highlights.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_achievements_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_achievements_.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_technical-releases_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_media-releases_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_speeches_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_about_highlights_achievements_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_blooming-flower-hanabii-pacifier-wins-2024-kyoto-global-design-award_.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_ai-sampling-singapore-project-blt-built-design-awards-2024_.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_world-cities-summit-young-leaders-2024_.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_congratulations-to-asd-alumni-ian-soon-on-winning-directors-choice-the-warming-competition-2021_.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_congratulations-to-asd-alumni-tan-gee-yang-on-winning-3rd-prize-in-fentress-global-challenge-2021_.html
# Saved webpage: www.sutd.edu.sg_asd_achievements-listing_forming-unforming-and-yue-hai-qing-miao-jian-zhu-yu-li-shi-de-dui-hua-win-the-golden-pin-design-award-2021_.html
# ...
# Saved webpage: www.sutd.edu.sg_profile_angela-wang-bo_.html
# Saved webpage: www.sutd.edu.sg_istd_achievements-listing_llm-agents-mooc-hackathon-2025_.html
# Saved webpage: www.sutd.edu.sg_profile_marie-therese-siew-hui-lin.html
# Saved webpage: www.sutd.edu.sg_istd_education_.html
# Saved webpage: www.sutd.edu.sg_smt_.html
# Saved webpage: www.sutd.edu.sg_smt_education.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_courses_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-ic-design-failure-analysis-and-reliability_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-advanced-ic-design-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_research.html
# Saved webpage: www.sutd.edu.sg_smt_people_.html
# Saved webpage: www.sutd.edu.sg_smt_people_researchers_.html
# Saved webpage: www.sutd.edu.sg_smt_people_students_.html
# Saved webpage: www.sutd.edu.sg_smt_people_staff_.html
# Saved webpage: www.sutd.edu.sg_smt_about.html
# Saved webpage: www.sutd.edu.sg_smt_about_news.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate.html
# Saved webpage: www.sutd.edu.sg_smt_smt_education_undergraduate.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_courses_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_minors_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_courses_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-018-design-thinking-project-i_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_sumbul-khan_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-019-design-thinking-project-ii_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-020-design-thinking-project-iii_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-101-technologies-for-sustainable-global-health_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_shireen-goh_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_yajuan-julia-zhu_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-114-instructional-design-of-serious-games-for-healthcare_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-115-science-of-sound-acoustics-audio-music_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_chen-jer-ming_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-117-brain-inspired-computing-and-its-applications_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_desmond-loke_.html
# Saved webpage: www.sutd.edu.sg_smt_course_01-119-nanoelectronics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_profile_shubhakar-kalya_.html
# Saved webpage: www.sutd.edu.sg_smt_course_10-013-modelling-and-analysis_.html
# Saved webpage: www.sutd.edu.sg_smt_course_10-015-physical-world_.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_courses_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_contact-us_.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_.html
# Saved webpage: www.sutd.edu.sg_smt_education_undergraduate_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_smt_about_.html
# Saved webpage: www.sutd.edu.sg_smt_about_news_.html
# Saved webpage: www.sutd.edu.sg_smt_smt_about.html
# Saved webpage: www.sutd.edu.sg_smt_about_news_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_national-stem-championship-winners-showcase-projects-with-significant-real-world-application-potential_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_dr-lee-chee-huei-and-dr-ching-chee-leong-featured-on-berita-harian_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_associate-prof-desmond-loke-featured-on-techiexpert-and-phys-org-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_assistant-professor-liu-xiaogang-featured-on-antpedia-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_dr-lee-chee-huei-featured-on-the-straits-times_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_asst-prof-liu-xiaogang-featured-in-royal-society-of-chemistry-rsc-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_asst-prof-desmond-loke-featured-in-phys-org-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_associate-prof-dario-poletti-featured-on-scienmag-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_news-listing_assistant-professor-desmond-loke-featured-in-tech-xplore-science-mathematics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_smt_about_news_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_about_news_%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_about_news_%3Fpaged%3D5%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_.html
# Saved webpage: www.sutd.edu.sg_smt_smt_about_highlights.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_achievements_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_technical-releases_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_media-releases_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_speeches_%23tabs.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_achievements_.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_%23popup-sidebar-content.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-associate-professor-liu-xiaogangs-phd-student-in-winning-the-royal-society-of-chemistry-rsc-excellent-student-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-assistant-professor-ang-yee-sin-for-receiving-the-young-scientist-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_faculty-and-staff-achievements-techconnect-2024-global-innovation-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-associate-professor-desmond-lokes-lab-for-receiving-the-2024-techconnect-innovation-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-associate-professor-liu-xiaogangs-phd-student-in-winning-the-merit-award-in-the-visual-science-cover-contest_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-associate-professor-liu-xiaogangs-phd-student-in-winning-the-best-oral-presentation-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-assistant-professor-ang-yee-sins-researcher-in-winning-the-best-oral-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_centre-for-quantum-technologies-cqt-fellow-associate-professor-dario-poletti_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-associate-professor-wu-lins-graduate-student-in-winning-the-best-student-paper-award_.html
# Saved webpage: www.sutd.edu.sg_smt_achievements-listing_congratulations-to-assistant-professor-ang-yee-sins-research-team-in-winning-two-awards-in-the-isafm2-conference_.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_achievements_%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_achievements_%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_smt_about_highlights_achievements_%3Fpaged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_mentorship-programmes_research-mentorship-programme_%23tabs.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_mentorship-programmes_moe-innovation-programme_%23tabs.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_sites_2_2024_12_foong-et-al-steamxd-workshop-for-pre-uni-students.pdf.pdf
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_ai-rescue-robots-track-programme-schedule_.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_%23media-tile-lightbox-1.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_drone-technologies-track-programme-schedule_.html
# Saved webpage: www.sutd.edu.sg_innovation_davincisutd_steamxd-immersion-programme_immersion-programme-2024_%23media-tile-lightbox-2.html
# Saved webpage: www.sutd.edu.sg_course_redesigning-education-the-sutd-way_.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_executive-programme_register-your-interest_%3Fcoursename%3Dredesigning-education-the-sutd-way.html
# Saved webpage: www.sutd.edu.sg_course_redesigning-education-the-sutd-way_%23tabs.html
# Saved webpage: www.sutd.edu.sg_course_redesigning-education-the-sutd-way_programme-outline_%23tabs.html
# Saved webpage: www.sutd.edu.sg_course_redesigning-education-the-sutd-way_course-fees_%23tabs.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_courses-and-modules_%3Facademy-type-course%3D1788.html
# Saved webpage: www.sutd.edu.sg_admissions_academy_get-in-touch_.html
# Saved PDF: www.sutd.edu.sg_wp-content_uploads_2024_10_SUTD.pdf.pdf
# Saved webpage: www.sutd.edu.sg_smt_news-listing_in-experiments-superconducting-qubit-baths-give-clean-simulation-of-quantum-transport_.html
# Saved webpage: www.sutd.edu.sg_hass_www.sutd.edu.sg_education_undergraduate_majors.html
# Saved webpage: www.sutd.edu.sg_hass_education.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors_.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_faq_.html
# Saved webpage: www.sutd.edu.sg_programme-listing_mtd-human-centred-design_.html
# Saved webpage: www.sutd.edu.sg_hass_research.html
# Saved webpage: www.sutd.edu.sg_hass_people_.html
# Saved webpage: www.sutd.edu.sg_hass_people_faculty.html
# Saved webpage: www.sutd.edu.sg_hass_people_researchers_%23tabs.html
# Saved webpage: www.sutd.edu.sg_hass_people_students_%23tabs.html
# Saved webpage: www.sutd.edu.sg_hass_people_staff_%23tabs.html
# Saved webpage: www.sutd.edu.sg_hass_about.html
# Saved webpage: www.sutd.edu.sg_hass_about_news.html
# Saved webpage: www.sutd.edu.sg_hass_about_events.html
# Saved webpage: www.sutd.edu.sg_hass_about_highlights.html
# Saved webpage: www.sutd.edu.sg_hass_about_testimonials_.html
# Saved webpage: www.sutd.edu.sg_about_careers_ssrc-graduate-research-fellowship_.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors.html
# Saved webpage: www.sutd.edu.sg_hass_hass_education_undergraduate_minors.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_courses_%23tabs.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors_digital-humanities-minor_%23tabs.html
# Saved PDF: www.sutd.edu.sg_hass_wp-content_uploads_sites_9_2024_12_HASS-Minor-Admission-Procedures-v.2024.07.15_b1a2b2.pdf.pdf
# Saved webpage: www.sutd.edu.sg_hass_contact-us_.html
# Saved webpage: www.sutd.edu.sg_contact-us_getting-around-sutd.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_minors.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_majors_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_majors_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_minors_%23tabs.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_specialisation-tracks_%23tabs.html
# Saved webpage: www.sutd.edu.sg_asd_education_undergraduate_curriculum.html
# Saved webpage: www.sutd.edu.sg_about_happenings_publicity_brochures.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_specialisation-tracks_.html
# Saved webpage: www.sutd.edu.sg_epd_education_undergraduate_specialisation-tracks_.html
# Saved webpage: www.sutd.edu.sg_epd_education_undergraduate_specialisation-tracks_%23media-tile-lightbox-1.html
# Saved webpage: www.sutd.edu.sg_esd_education_undergraduate_minors_analytics_.html
# Saved webpage: www.sutd.edu.sg_esd_education_undergraduate_minors.html
# Saved webpage: www.sutd.edu.sg_esd_esd_education_undergraduate_minors.html
# Saved webpage: www.sutd.edu.sg_course_50-038-computational-data-science_.html
# Saved webpage: www.sutd.edu.sg_course_40-319-statistical-and-machine-learning_.html
# Saved webpage: www.sutd.edu.sg_course_30-114-advanced-feedback-and-control_.html
# Saved webpage: www.sutd.edu.sg_course_30-115-digital-signal-processing_.html
# Saved webpage: www.sutd.edu.sg_course_40-316-game-theory_.html
# Saved webpage: www.sutd.edu.sg_course_50-021-artificial-intelligence_.html
# Saved webpage: www.sutd.edu.sg_course_50-039-theory-and-practice-of-deep-learning_.html
# Saved webpage: www.sutd.edu.sg_course_50-035-computer-vision_.html
# Saved webpage: www.sutd.edu.sg_course_50-040-natural-language-processing_.html
# Saved webpage: www.sutd.edu.sg_course_50-043-database-systems_.html
# Saved webpage: www.sutd.edu.sg_course_50-045-information-retrieval_.html
# Saved webpage: www.sutd.edu.sg_course_50-050-discrete-mathematics-and-algorithm-design_.html
# Saved webpage: www.sutd.edu.sg_course_50-055-special-topic-machine-learning-operations_.html
# Saved webpage: www.sutd.edu.sg_esd_education_undergraduate_minors_engineering-systems_.html
# Saved webpage: www.sutd.edu.sg_course_01-106-engineering-management_.html
# Saved webpage: www.sutd.edu.sg_profile_dawn-tan.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fcourse-term%3D861.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fpillar-cluster%3D44.html
# Saved webpage: www.sutd.edu.sg_course_30-120-design-manufacturing_.html
# Saved webpage: www.sutd.edu.sg_course_10-015-physical-world.html
# Saved webpage: www.sutd.edu.sg_profile_tan-u-xuan_.html
# Saved webpage: www.sutd.edu.sg_epd_education_undergraduate_minor-programmes_dive-minor_.html
# Saved webpage: www.sutd.edu.sg_course_30-111-entrepreneurship_.html
# Saved webpage: www.sutd.edu.sg_profile_mohan-rajesh-elara_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fcourse-type%3D854.html
# Saved webpage: www.sutd.edu.sg_epd_education_undergraduate_minor-programmes_healthcare-informatics-minor_.html
# Saved webpage: www.sutd.edu.sg_course_02-230ht-health-communication-and-behavior-change_.html
# Saved webpage: www.sutd.edu.sg_course_01-116-ai-for-healthcare_.html
# Saved webpage: www.sutd.edu.sg_course_50-007-machine-learning.html
# Saved webpage: www.sutd.edu.sg_course_40-319-statistical-and-machine-learning.html
# Saved webpage: www.sutd.edu.sg_profile_cheung-ngai-man.html
# Saved webpage: www.sutd.edu.sg_profile_khoo-xiaojuan.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D879.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D880.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D881.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D882.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D883.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fspecialisation-track%3D884.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fpillar-cluster%3D11.html
# Saved webpage: www.sutd.edu.sg_course_01-101-technologies-for-sustainable-global-health_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses_%3Fpillar-cluster%3D45.html
# Saved webpage: www.sutd.edu.sg_course_01-114-instructional-design-of-serious-games-for-healthcare_.html
# Saved webpage: www.sutd.edu.sg_course_30-203-topics-in-biomedical-and-healthcare-engineering_.html
# Saved webpage: www.sutd.edu.sg_course_10-016-science-for-a-sustainable-world.html
# Saved webpage: www.sutd.edu.sg_profile_shireen-goh.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors_human-centred-design-minor_.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors_%23tabs.html
# Saved webpage: www.sutd.edu.sg_hass_education_undergraduate_minors_psychology-business-management-minor_.html

# %%
# Scraping undergraduate course websites
def crawl_course_page(course_url, output_folder):
    try:
        response = requests.get(course_url)
    except Exception as e:
        print(f"Failed to fetch {course_url}: {e}")
        return
    
    content_type = response.headers.get('Content-Type', '')
    
    if 'application/pdf' in content_type:
        download_pdf(course_url, output_folder)
        return

    if 'text/html' not in content_type:
        return
    
    filename = create_filename(course_url, extension=".html")
    file_path = os.path.join(output_folder, filename)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(response.text)
    print(f"Saved webpage: {filename}")

def crawl_courses_page(page_url, output_folder, base_netloc):
    try:
        response = requests.get(page_url)
    except Exception as e:
        print(f"Failed to fetch {page_url}: {e}")
        return
    
    soup = BeautifulSoup(response.text, 'html.parser')

    for link in soup.find_all('a', href=True):
        href = link['href']
        if "course" in href:
            course_url = urljoin(page_url, href)
            if is_valid(course_url, base_netloc):
                crawl_course_page(course_url, output_folder)

def crawl_all_courses(base_url, output_folder, base_netloc, total_pages=20):
    for page_number in range(1, total_pages + 1):
        page_url = f"{base_url}?paged={page_number}#general-listing"
        print(f"Crawling page {page_number}: {page_url}")
        crawl_courses_page(page_url, output_folder, base_netloc)

output_folder = 'downloaded_docs'
os.makedirs(output_folder, exist_ok=True)
base_url = "https://www.sutd.edu.sg/education/undergraduate/courses"
base_netloc = urlparse(base_url).netloc

crawl_all_courses(base_url, output_folder, base_netloc, total_pages=20)
# Out:
# Crawling page 1: https://www.sutd.edu.sg/education/undergraduate/courses?paged=1#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_01-018-design-thinking-project-i_.html
# Saved webpage: www.sutd.edu.sg_course_01-019-design-thinking-project-ii_.html
# Saved webpage: www.sutd.edu.sg_course_01-020-design-thinking-project-iii_.html
# Saved webpage: www.sutd.edu.sg_course_01-101-technologies-for-sustainable-global-health_.html
# Saved webpage: www.sutd.edu.sg_course_01-102-energy-systems-and-management_.html
# Saved webpage: www.sutd.edu.sg_course_01-106-engineering-management_.html
# Saved webpage: www.sutd.edu.sg_course_01-107-urban-transportation_.html
# Saved webpage: www.sutd.edu.sg_course_01-114-instructional-design-of-serious-games-for-healthcare_.html
# Saved webpage: www.sutd.edu.sg_course_01-115-science-of-sound-acoustics-audio-music_.html
# Saved webpage: www.sutd.edu.sg_course_01-117-brain-inspired-computing-and-its-applications_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D2%23general-listing.html
# Crawling page 2: https://www.sutd.edu.sg/education/undergraduate/courses?paged=2#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_01-119-nanoelectronics-and-technology_.html
# Saved webpage: www.sutd.edu.sg_course_02-001-global-humanities-literature-philosophy-and-ethics_.html
# Saved webpage: www.sutd.edu.sg_course_02-003-social-science-understanding-behaviour-culture-society_.html
# Saved webpage: www.sutd.edu.sg_course_02-102-ht-the-world-since-1400_.html
# Saved webpage: www.sutd.edu.sg_course_02-104ts-the-history-of-international-development-in-asia-the-role-of-engineers-and-designers_.html
# Saved webpage: www.sutd.edu.sg_course_02-108dh-modern-china-pluralism-and-beyond-territoriality_.html
# Saved webpage: www.sutd.edu.sg_course_02-110dh-the-chinese-lyrical-tradition-arts-literature-and-landscape-design_.html
# Saved webpage: www.sutd.edu.sg_course_02-120dh-history-of-traditional-chinese-short-fiction_.html
# Saved webpage: www.sutd.edu.sg_course_02-121dh-the-question-of-being_.html
# Saved webpage: www.sutd.edu.sg_course_02-124dh-the-modern-east-asian-nexus-a-history_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D3%23general-listing.html
# Crawling page 3: https://www.sutd.edu.sg/education/undergraduate/courses?paged=3#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_02-128dh-classical-south-and-southeast-asian-literature-and-art_.html
# Saved webpage: www.sutd.edu.sg_course_02-132dh-being-and-time_.html
# Saved webpage: www.sutd.edu.sg_course_02-135ht-the-question-of-technology_.html
# Saved webpage: www.sutd.edu.sg_course_02-137dh-introduction-to-digital-humanities_.html
# Saved webpage: www.sutd.edu.sg_course_02-140ts-shaping-futures-innovation-work-and-society_.html
# Saved webpage: www.sutd.edu.sg_course_02-143-artificial-intelligence-and-ethics_.html
# Saved webpage: www.sutd.edu.sg_course_02-144dh-being-in-the-world-from-homer-and-heidegger-to-a-i_.html
# Saved webpage: www.sutd.edu.sg_course_02-146-financing-cities-of-the-future-theory-and-practice_.html
# Saved webpage: www.sutd.edu.sg_course_02-147ts-interventions-in-design-technology-and-society_.html
# Saved webpage: www.sutd.edu.sg_course_02-148ht-geographies-of-money-and-finance_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D2%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D4%23general-listing.html
# Crawling page 4: https://www.sutd.edu.sg/education/undergraduate/courses?paged=4#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_02-151ht-digital-worlds-space-and-spatialities-geographical-perspectives-on-digitalisation_.html
# Saved webpage: www.sutd.edu.sg_course_02-152ts-urban-theory_.html
# Saved webpage: www.sutd.edu.sg_course_02-153ts-a-history-of-nuclear-strategy-design-technology-and-society_.html
# Saved webpage: www.sutd.edu.sg_course_02-156dh-games-of-histories_.html
# Saved webpage: www.sutd.edu.sg_course_02-158dh-kings-monks-and-merchants-a-history-of-asia-before-1750_.html
# Saved webpage: www.sutd.edu.sg_course_02-159ht-equitable-tech-reimagining-our-digital-infrastructures_.html
# Saved webpage: www.sutd.edu.sg_course_02-163-international-trade-free-trade-governance-and-technology_.html
# Saved webpage: www.sutd.edu.sg_course_02-164dh-performance-design-dramaturgy-and-interpretation_.html
# Saved webpage: www.sutd.edu.sg_course_02-165ts-empathy-an-interdisciplinary-concept-special-topics_.html
# Saved webpage: www.sutd.edu.sg_course_02-166ts-urban-southeast-asia-diversity-sustainability-and-change_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D3%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D5%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D5%23general-listing.html
# Crawling page 5: https://www.sutd.edu.sg/education/undergraduate/courses?paged=5#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_02-167ht-fashion-east-and-west-special-topics_.html
# Saved webpage: www.sutd.edu.sg_course_02-170ht-history-of-surveillance-in-modern-asia_.html
# Saved webpage: www.sutd.edu.sg_course_02-171-religion-society-in-southeast-asia-special-topics_.html
# Saved webpage: www.sutd.edu.sg_course_02-172dh-imagine-dragons-monsters-and-outcasts-in-literature-from-beowulf-to-murakami_.html
# Saved webpage: www.sutd.edu.sg_course_02-173dh-the-medium-and-the-message-an-introduction-to-media-theory_.html
# Saved webpage: www.sutd.edu.sg_course_02-174ts-the-design-of-digital-platforms_.html
# Saved webpage: www.sutd.edu.sg_course_02-175dh-global-film-art-and-technology_.html
# Saved webpage: www.sutd.edu.sg_course_02-176-collective-behavior_.html
# Saved webpage: www.sutd.edu.sg_course_02-177-on-wind-water-metaphysics-design-and-technology-special-topics_.html
# Saved webpage: www.sutd.edu.sg_course_02-178ht-human-existence-and-technology-a-historical-and-philosophical-inquiry-special-topics_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D4%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D6%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D6%23general-listing.html
# Crawling page 6: https://www.sutd.edu.sg/education/undergraduate/courses?paged=6#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_02-201ts-digital-sociology_.html
# Saved webpage: www.sutd.edu.sg_course_02-202-organizational-processes_.html
# Saved webpage: www.sutd.edu.sg_course_02-203-psychological-approaches-to-bilingualism_.html
# Saved webpage: www.sutd.edu.sg_course_02-204-technology-and-the-self_.html
# Saved webpage: www.sutd.edu.sg_course_02-208-microeconomics_.html
# Saved webpage: www.sutd.edu.sg_course_02-210ts-who-gets-ahead-sociology-of-social-networks-and-social-capital_.html
# Saved webpage: www.sutd.edu.sg_course_02-211-critical-management-skills_.html
# Saved webpage: www.sutd.edu.sg_course_02-216ts-human-behaviour-technology-and-design_.html
# Saved webpage: www.sutd.edu.sg_course_02-217-gender-sexuality-and-society_.html
# Saved webpage: www.sutd.edu.sg_course_02-218-introduction-to-psychology_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D5%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D5%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D7%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D7%23general-listing.html
# Crawling page 7: https://www.sutd.edu.sg/education/undergraduate/courses?paged=7#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_02-219ts-rice-cultures-technology-society-and-environment-in-asia_.html
# Saved webpage: www.sutd.edu.sg_course_02-222ts-unnatural-disasters_.html
# Saved webpage: www.sutd.edu.sg_course_02-226-leaders-followers_.html
# Saved webpage: www.sutd.edu.sg_course_02-228ts-design-in-the-anthropocene_.html
# Saved webpage: www.sutd.edu.sg_course_02-230ts-health-communication-and-behavior-change_.html
# Saved webpage: www.sutd.edu.sg_course_02-231ts-transportation-technology-and-policy-in-urban-progress_.html
# Saved webpage: www.sutd.edu.sg_course_03-007-design-thinking-and-innovation_.html
# Saved webpage: www.sutd.edu.sg_course_10-013-modelling-and-analysis_.html
# Saved webpage: www.sutd.edu.sg_course_10-014-computational-thinking-for-design_.html
# Saved webpage: www.sutd.edu.sg_course_10-015-physical-world_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D6%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D6%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D8%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D8%23general-listing.html
# Crawling page 8: https://www.sutd.edu.sg/education/undergraduate/courses?paged=8#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_10-016-science-for-a-sustainable-world_.html
# Saved webpage: www.sutd.edu.sg_course_10-017-technological-world_.html
# Saved webpage: www.sutd.edu.sg_course_10-018-modelling-space-and-systems_.html
# Saved webpage: www.sutd.edu.sg_course_10-019-science-and-technology-for-healthcare-elective_.html
# Saved webpage: www.sutd.edu.sg_course_10-020-data-driven-world-elective_.html
# Saved webpage: www.sutd.edu.sg_course_10-022-modelling-uncertainty_.html
# Saved webpage: www.sutd.edu.sg_course_10-023-designing-energy-systems-elective_.html
# Saved webpage: www.sutd.edu.sg_course_10-024-spatial-design-world_.html
# Saved webpage: www.sutd.edu.sg_course_20-099-urban-sketching_.html
# Saved webpage: www.sutd.edu.sg_course_20-101-architecture-core-studio-1_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D7%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D7%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D9%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D9%23general-listing.html
# Crawling page 9: https://www.sutd.edu.sg/education/undergraduate/courses?paged=9#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_20-102-architecture-core-studio-2_.html
# Saved webpage: www.sutd.edu.sg_course_20-103-architecture-core-studio-3_.html
# Saved webpage: www.sutd.edu.sg_course_20-111-sustainable-design-option-studio-1_.html
# Saved webpage: www.sutd.edu.sg_course_20-112-sustainable-design-option-studio-2_.html
# Saved webpage: www.sutd.edu.sg_course_20-201-architecture-science-technology_.html
# Saved webpage: www.sutd.edu.sg_course_20-202-architectural-structure-enclosure-design_.html
# Saved webpage: www.sutd.edu.sg_course_20-203-architectural-energy-systems_.html
# Saved webpage: www.sutd.edu.sg_course_20-212-digital-design-and-fabrication_.html
# Saved webpage: www.sutd.edu.sg_course_20-213-building-information-modeling_.html
# Saved webpage: www.sutd.edu.sg_course_20-221-traditions-world-history-connections-to-vernacular-architecture-htc_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D8%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D8%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D10%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D10%23general-listing.html
# Crawling page 10: https://www.sutd.edu.sg/education/undergraduate/courses?paged=10#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_20-222-modernism-technology-and-society-in-architecture-htc_.html
# Saved webpage: www.sutd.edu.sg_course_20-223-contemporary-architecture-between-technology-science-and-culture-htc-elective-2_.html
# Saved webpage: www.sutd.edu.sg_course_20-224-artificial-architectural-intelligences-in-design-htc-2_.html
# Saved webpage: www.sutd.edu.sg_course_20-301-material-computation-advanced-topics-in-geometry-and-matter_.html
# Saved webpage: www.sutd.edu.sg_course_20-302-advanced-topics-in-performative-design-daylight-and-electric-lighting_.html
# Saved webpage: www.sutd.edu.sg_course_20-303-urban-analysis_.html
# Saved webpage: www.sutd.edu.sg_course_20-304-urban-housing-typologies_.html
# Saved webpage: www.sutd.edu.sg_course_20-305-conservation-theories-and-approaches-of-built-heritage_.html
# Saved webpage: www.sutd.edu.sg_course_20-307-toward-carbon-neutral-architecture-and-urban-design_.html
# Saved webpage: www.sutd.edu.sg_course_20-312-social-architecture-theory-and-practice_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D9%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D9%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D11%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D11%23general-listing.html
# Crawling page 11: https://www.sutd.edu.sg/education/undergraduate/courses?paged=11#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_20-313-advanced-topics-in-performative-design-urban-sustainability_.html
# Saved webpage: www.sutd.edu.sg_course_20-314-paradigms-of-adaptation_.html
# Saved webpage: www.sutd.edu.sg_course_20-316-digital-biomimetics-sustainable-materials-and-manufacturing_.html
# Saved webpage: www.sutd.edu.sg_course_20-317-augmented-design_.html
# Saved webpage: www.sutd.edu.sg_course_20-318-creative-machine-learning_.html
# Saved webpage: www.sutd.edu.sg_course_20-319-architectural-theory-and-design-application-in-the-20th-21st-century_.html
# Saved webpage: www.sutd.edu.sg_course_20-320-project-management-in-the-built-environment_.html
# Saved webpage: www.sutd.edu.sg_course_20-321-architecture-acoustics_.html
# Saved webpage: www.sutd.edu.sg_course_20-322-net-zero-design-case-studies-for-whole-life-decarbonisation_.html
# Saved webpage: www.sutd.edu.sg_course_20-323-forms-and-types-of-media-representation_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D10%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D10%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D12%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D12%23general-listing.html
# Crawling page 12: https://www.sutd.edu.sg/education/undergraduate/courses?paged=12#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_30-001-structures-materials_.html
# Saved webpage: www.sutd.edu.sg_course_30-002-circuits-electronics_.html
# Saved webpage: www.sutd.edu.sg_course_30-007-engineering-design-innovation_.html
# Saved webpage: www.sutd.edu.sg_course_30-100-computational-and-data-driven-engineering_.html
# Saved webpage: www.sutd.edu.sg_course_30-101-systems-control_.html
# Saved webpage: www.sutd.edu.sg_course_30-102-electromagnetics-applications_.html
# Saved webpage: www.sutd.edu.sg_course_30-103-fluid-mechanics_.html
# Saved webpage: www.sutd.edu.sg_course_30-104-dynamics_.html
# Saved webpage: www.sutd.edu.sg_course_30-105-machine-element-design_.html
# Saved webpage: www.sutd.edu.sg_course_30-106-microelectronics-circuits-and-devices_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D11%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D11%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D13%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D13%23general-listing.html
# Crawling page 13: https://www.sutd.edu.sg/education/undergraduate/courses?paged=13#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_30-107-power-electronics_.html
# Saved webpage: www.sutd.edu.sg_course_30-108-material-science_.html
# Saved webpage: www.sutd.edu.sg_course_30-109-thermal-systems-for-power-environment_.html
# Saved webpage: www.sutd.edu.sg_course_30-110-digital-systems-laboratory_.html
# Saved webpage: www.sutd.edu.sg_course_30-111-entrepreneurship_.html
# Saved webpage: www.sutd.edu.sg_course_30-113-design-and-fabrication-of-microelectromechanical-systems-mems_.html
# Saved webpage: www.sutd.edu.sg_course_30-114-advanced-feedback-and-control_.html
# Saved webpage: www.sutd.edu.sg_course_30-115-digital-signal-processing_.html
# Saved webpage: www.sutd.edu.sg_course_30-117-electric-power-systems-analysis-and-design_.html
# Saved webpage: www.sutd.edu.sg_course_30-119-intelligent-robotics_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D12%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D12%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D14%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D14%23general-listing.html
# Crawling page 14: https://www.sutd.edu.sg/education/undergraduate/courses?paged=14#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_30-120-design-manufacturing_.html
# Saved webpage: www.sutd.edu.sg_course_30-123-healthcare-product-design_.html
# Saved webpage: www.sutd.edu.sg_course_30-200-micro-nano-projects-laboratory_.html
# Saved webpage: www.sutd.edu.sg_course_30-201-wireless-communications-and-internet-of-things_.html
# Saved webpage: www.sutd.edu.sg_course_30-202-design-of-intelligent-digital-integrated-circuits-and-systems_.html
# Saved webpage: www.sutd.edu.sg_course_30-203-topics-in-biomedical-and-healthcare-engineering_.html
# Saved webpage: www.sutd.edu.sg_course_30-303-industry-4-0-3d-printing_.html
# Saved webpage: www.sutd.edu.sg_course_30-316-digital-biomimetics-sustainable-materials-and-manufacturing_.html
# Saved webpage: www.sutd.edu.sg_course_40-002-optimisation_.html
# Saved webpage: www.sutd.edu.sg_course_40-011-data-and-business-analytics-for-esd-students-only_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D13%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D13%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D15%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D15%23general-listing.html
# Crawling page 15: https://www.sutd.edu.sg/education/undergraduate/courses?paged=15#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_40-012-manufacturing-and-service-operations_.html
# Saved webpage: www.sutd.edu.sg_course_40-014-engineering-systems-architecture_.html
# Saved webpage: www.sutd.edu.sg_course_40-015-simulation-modelling-and-analysis_.html
# Saved webpage: www.sutd.edu.sg_course_40-016-the-analytics-edge_.html
# Saved webpage: www.sutd.edu.sg_course_40-017-probability-and-statistics_.html
# Saved webpage: www.sutd.edu.sg_course_40-018-heuristics-and-systems-theory_.html
# Saved webpage: www.sutd.edu.sg_course_40-230-design-for-sustainability_.html
# Saved webpage: www.sutd.edu.sg_course_40-240-investment-science-for-esd-students-only_.html
# Saved webpage: www.sutd.edu.sg_course_40-242-derivative-pricing-and-risk-management_.html
# Saved webpage: www.sutd.edu.sg_course_40-260-supply-chain-management_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D14%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D14%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D16%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D16%23general-listing.html
# Crawling page 16: https://www.sutd.edu.sg/education/undergraduate/courses?paged=16#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_40-302-advanced-topics-in-optimisation_.html
# Saved webpage: www.sutd.edu.sg_course_40-305-advanced-topics-in-stochastic-modelling_.html
# Saved webpage: www.sutd.edu.sg_course_40-316-game-theory_.html
# Saved webpage: www.sutd.edu.sg_course_40-318-supply-chain-digitalisation-and-design_.html
# Saved webpage: www.sutd.edu.sg_course_40-319-statistical-and-machine-learning_.html
# Saved webpage: www.sutd.edu.sg_course_40-320-airport-systems-planning-and-design_.html
# Saved webpage: www.sutd.edu.sg_course_40-321-airport-systems-modelling-and-simulation_.html
# Saved webpage: www.sutd.edu.sg_course_40-323-equity-valuation_.html
# Saved webpage: www.sutd.edu.sg_course_40-324-fundamentals-of-investing_.html
# Saved webpage: www.sutd.edu.sg_course_50-001-information-systems-programming_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D15%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D15%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D17%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D17%23general-listing.html
# Crawling page 17: https://www.sutd.edu.sg/education/undergraduate/courses?paged=17#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_50-002-computation-structures_.html
# Saved webpage: www.sutd.edu.sg_course_50-003-elements-of-software-construction_.html
# Saved webpage: www.sutd.edu.sg_course_50-004-algorithms_.html
# Saved webpage: www.sutd.edu.sg_course_50-005-computer-system-engineering_.html
# Saved webpage: www.sutd.edu.sg_course_50-006-user-interface-design-and-implementation_.html
# Saved webpage: www.sutd.edu.sg_course_50-007-machine-learning_.html
# Saved webpage: www.sutd.edu.sg_course_50-012-networks_.html
# Saved webpage: www.sutd.edu.sg_course_50-017-graphics-and-visualisation_.html
# Saved webpage: www.sutd.edu.sg_course_50-020-network-security_.html
# Saved webpage: www.sutd.edu.sg_course_50-021-artificial-intelligence_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D16%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D16%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D18%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D18%23general-listing.html
# Crawling page 18: https://www.sutd.edu.sg/education/undergraduate/courses?paged=18#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_50-033-foundations-of-game-design-and-development_.html
# Saved webpage: www.sutd.edu.sg_course_50-035-computer-vision_.html
# Saved webpage: www.sutd.edu.sg_course_50-037-blockchain-technology_.html
# Saved webpage: www.sutd.edu.sg_course_50-038-computational-data-science_.html
# Saved webpage: www.sutd.edu.sg_course_50-039-theory-and-practice-of-deep-learning_.html
# Saved webpage: www.sutd.edu.sg_course_50-040-natural-language-processing_.html
# Saved webpage: www.sutd.edu.sg_course_50-041-distributed-systems-and-computing_.html
# Saved webpage: www.sutd.edu.sg_course_50-042-foundations-of-cybersecurity_.html
# Saved webpage: www.sutd.edu.sg_course_50-043-database-systems_.html
# Saved webpage: www.sutd.edu.sg_course_50-044-system-security_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D17%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D17%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D19%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D19%23general-listing.html
# Crawling page 19: https://www.sutd.edu.sg/education/undergraduate/courses?paged=19#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_50-045-information-retrieval_.html
# Saved webpage: www.sutd.edu.sg_course_50-046-cloud-computing-and-internet-of-things_.html
# Saved webpage: www.sutd.edu.sg_course_50-047-mobile-robotics_.html
# Saved webpage: www.sutd.edu.sg_course_50-050-discrete-mathematics-and-algorithm-design_.html
# Saved webpage: www.sutd.edu.sg_course_50-051-programming-language-concepts_.html
# Saved webpage: www.sutd.edu.sg_course_50-052-extended-reality_.html
# Saved webpage: www.sutd.edu.sg_course_50-053-software-testing-and-verification_.html
# Saved webpage: www.sutd.edu.sg_course_50-054-compiler-design-and-program-analysis_.html
# Saved webpage: www.sutd.edu.sg_course_50-055-special-topic-machine-learning-operations_.html
# Saved webpage: www.sutd.edu.sg_course_50-056-software-abstraction-functional-programming_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D18%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D18%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D20%23general-listing.html
# Crawling page 20: https://www.sutd.edu.sg/education/undergraduate/courses?paged=20#general-listing
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses.html
# Saved webpage: www.sutd.edu.sg_course_60-001-applied-deep-learning_.html
# Saved webpage: www.sutd.edu.sg_course_60-002-ai-applications-in-design_.html
# Saved webpage: www.sutd.edu.sg_course_60-003-product-design-studio_.html
# Saved webpage: www.sutd.edu.sg_course_60-004-service-design-studio_.html
# Saved webpage: www.sutd.edu.sg_course_60-005-hci-and-ai_.html
# Saved webpage: www.sutd.edu.sg_course_60-006-spatial-design-studio_.html
# Saved webpage: www.sutd.edu.sg_course_60-008-systems-design-studio_.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D19%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D1%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D18%23general-listing.html
# Saved webpage: www.sutd.edu.sg_education_undergraduate_courses%3Fpaged%3D19%23general-listing.html

# %% [markdown]
# # Split documents
# Use LangChain to split the documents into smaller text chunks.

# %%
# QUESTION: Use langchain to split the documents into chunks 

#--- ADD YOUR SOLUTION HERE (20 points)---
# Clean documents to remove whitespace + newline
def clean_text(text):
    soup = BeautifulSoup(text, "html.parser")
    text = soup.get_text(separator=" ")
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# Process PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

download_folder = "downloaded_docs"
documents = []

# Process HTML
html_files = [
    os.path.join(download_folder, f)
    for f in os.listdir(download_folder)
    if f.lower().endswith(".html")
]
for file in html_files:
    if os.path.getsize(file) > 0:
        try:
            loader = UnstructuredHTMLLoader(file)
            docs = loader.load()
            for doc in docs:
                doc.page_content = clean_text(doc.page_content)
            documents.extend(docs)
        except Exception as e:
            print(f"Error processing {file}: {e}")
    else:
        print(f"Skipping empty file: {file}")

pdf_files = [
    os.path.join(download_folder, f)
    for f in os.listdir(download_folder)
    if f.lower().endswith(".pdf")
]
for file in pdf_files:
    text = extract_text_from_pdf(file)
    text = clean_text(text)
    document = Document(page_content=text)
    documents.append(document)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=256,
    chunk_overlap=50
)
split_docs = text_splitter.split_documents(documents)
print(f"Total number of chunks created: {len(split_docs)}")
# Out:
# Skipping empty file: downloaded_docs/www.sutd.edu.sg_global_team.html
# Total number of chunks created: 22071

# %% [markdown]
# ### QUESTION:
#
# What chunking method or strategy did you use? Why did you use this method. Explain your design decision in less than 10 sentences.
#
#
# **--- ADD YOUR SOLUTION HERE (10 points) ---**
#
# We used LangChain's `RecursiveCharacterTextSplitter` to split the documents. For pre-processing, we designed appropriate data loaders for our two datatypes, PDF and HTML, as well as a function to clean the document before chunking. Then, it breaks text into manageable chunks (size 256) while including overlapping sections between chunks (size 50) to preserve context. The overlapping helps maintain continuity, ensuring that important details spanning chunk boundaries aren't lost. We chose this approach because it is flexible, allowing for adjustable chunk sizes and overlap lengths. This balance between chunk size and context retention is ideal for processing with language models that have token limits.
#
# ------------------------------

# %%
# QUESTION: create embeddings of document chunks and store them in a local vector store for fast lookup
# Decide an appropriate embedding model. Use Huggingface to run the embedding model locally.
# You do not have to use cloud-based APIs.

#--- ADD YOUR SOLUTION HERE (20 points)---
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
vector_store = FAISS.from_documents(split_docs, embedding_model)
vector_store.save_local("faiss_index")
#------------------------------
# Out:
# /var/folders/8f/56qvs3bd6jsbf5sy0qgrzr680000gn/T/ipykernel_14573/4093568086.py:6: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# %% [markdown]
# ### QUESTION:
#
# What embeddings and vector store did you use and why? Explain your design decision in less than 10 sentences.
#
#
# **--- ADD YOUR SOLUTION HERE (10 points) ---**<br>
# We selected the `"sentence-transformers/all-mpnet-base-v2"` model for generating embeddings because it provides a strong balance between semantic accuracy and computational efficiency, capturing contextual nuances effectively. FAISS provides efficient similarity search capabilities for fast retrieval, and using LangChain’s wrappers simplifies integration. This combination ensures that our retrieval-augmented generation system can quickly and accurately fetch relevant document chunks.

# %%
# Execute a query against the vector store

query = "When was SUTD founded?"

# QUESTION: run the query against the vector store, print the top 5 search results

#--- ADD YOUR SOLUTION HERE (5 points)---
# This is a hybrid search approach that leverages similarity search and BM25.
dense_results = vector_store.similarity_search(query, k=20)
candidate_texts = [doc.page_content for doc in dense_results]
tokenized_candidates = [word_tokenize(text.lower()) for text in candidate_texts]
tokenized_query = word_tokenize(query.lower())
bm25 = BM25Okapi(tokenized_candidates)
scores = bm25.get_scores(tokenized_query)
top_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]

for rank, idx in enumerate(top_indices):
    print(f"Rank {rank+1} (BM25 score: {scores[idx]:.2f}):")
    print(candidate_texts[idx])
    print("-" * 50)
#------------------------------
# Out:
# Rank 1 (BM25 score: 4.51):
# in school. SUTD has since witnessed over seven start-ups and even more in the pipeline. In 2017, SUTD was awarded the maximum accreditation tenure of five years across all of its undergraduate engineering and architecture programmes. This was granted
# --------------------------------------------------
# Rank 2 (BM25 score: 2.84):
# of not going to University, back in 2017 when I caught the Start-up bug. But I am so happy to have joined SUTD. For the past 3.5 years, I have grown tremendously – with my feet planted on firm technical foundation, and my eyes on the stars. Lionell Jian
# --------------------------------------------------
# Rank 3 (BM25 score: 0.91):
# Partnering with SUTD Giving Partnering with SUTD Giving to SUTD The philanthropic efforts of our fellow donors play a key role in our mission to nurture the next generations of leaders and innovators. Find out how our benefactors have paid it forward by
# --------------------------------------------------
# Rank 4 (BM25 score: 0.90):
# ranking fifth in The Straits Times‘ annual list. SUTD’s Associate Professor Mohan Rajesh Elara is one of the company’s founders. SUTD faculty recognised globally for exceptional research in Clarivate’s Highly Cited Researchers 2024 21 November 2024 SUTD
# --------------------------------------------------
# Rank 5 (BM25 score: 0.79):
# and relax. About SUTD The Singapore University of Technology and Design (SUTD) is one of the first universities in the world to incorporate the art and science of design and technology into a truly holistic interdisciplinary education and research
# --------------------------------------------------

# %%
# QUESTION: Use the Huggingface transformers library to load the Llama 3.2-3B instruct model
# https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct
# Run the model locally. You do not have to use cloud-based APIs.

# Execute the below query against the model and let it it answer from it's internal memory

query = "What courses are available in SUTD?"


#--- ADD YOUR SOLUTION HERE (40 points)---
login(token="")
model_name = "meta-llama/Llama-3.2-3B-Instruct"
device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
print(f"Model is running on: {model.device}")
inputs = tokenizer(query, return_tensors="pt", padding=True, truncation=True).to(device)
with torch.no_grad():
    outputs = model.generate(**inputs, max_length=512, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(answer)
#------------------------------
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Model is running on: cpu
# What courses are available in SUTD? offered by Singapore-MIT Alliance for Research and Technology (SMART)
# The Singapore-MIT Alliance for Research and Technology (SMART) offers a range of courses in various disciplines, including engineering, computer science, and life sciences. Here are some of the courses available in SMART:
#
# **Engineering Courses:**
#
# 1. Master of Science in Engineering (MSE) in various disciplines, including:
# 	* Electrical Engineering and Computer Science (EECS)
# 	* Mechanical Engineering
# 	* Materials Science and Engineering
# 	* Biomedical Engineering
# 2. Master of Science in BioSystems and Micromechanics (MSc) in BioSystems and Micromechanics
# 3. Master of Science in Energy (MSE) in Energy
# 4. Master of Science in Engineering (MSE) in Environmental Engineering
# 5. Master of Science in Computer Science (MSCS) in Computer Science
#
# **Computer Science Courses:**
#
# 1. Master of Science in Computer Science (MSCS) in Artificial Intelligence
# 2. Master of Science in Computer Science (MSCS) in Data Science
# 3. Master of Science in Computer Science (MSCS) in Human-Computer Interaction
# 4. Master of Science in Computer Science (MSCS) in Software Engineering
#
# **Life Sciences Courses:**
#
# 1. Master of Science in BioSystems and Micromechanics (MSc) in BioSystems and Micromechanics
# 2. Master of Science in Biomedical Engineering (MSE) in Biomedical Engineering
# 3. Master of Science in Environmental Science (MSE) in Environmental Science
#
# **Other Courses:**
#
# 1. Master of Science in Engineering (MSE) in Sustainable Energy
# 2. Master of Science in Engineering (MSE) in Materials Science and Engineering
# 3. Master of Science in Engineering (MSE) in Biomedical Engineering
#
# Please note that this is not an exhaustive list, and courses are subject to change. It's best to check the SMART website or contact their admissions office for the most up-to-date information on available courses. Additionally, SUTD students can also take advantage of the SMART exchange program, which allows them to take courses at the Massachusetts Institute of Technology (MIT) or other SMART partner institutions.

# %%
# QUESTION: Now put everything together. Use langchain to integrate your vector store and Llama model into a RAG system
# Run the below example question against your RAG system.

# Example questions
query = "How can I increase my chances of admission into SUTD?"


#--- ADD YOUR SOLUTION HERE (40 points)---
# Context retrieval
dense_results = vector_store.similarity_search(query, k=20)
candidate_texts = [doc.page_content for doc in dense_results]
tokenized_candidates = [word_tokenize(text.lower()) for text in candidate_texts]
tokenized_query = word_tokenize(query.lower())
bm25 = BM25Okapi(tokenized_candidates)
scores = bm25.get_scores(tokenized_query)
top_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]

print("Context:")
context_chunks = []
for rank, idx in enumerate(top_indices):
    bm25_score = scores[idx]
    chunk = candidate_texts[idx]
    context_chunks.append(f"BM25 Score: {bm25_score:.2f}\n{chunk}")
    print(f"Chunk {rank+1}:")
    print(f"BM25 Score: {bm25_score:.2f}")
    print(chunk)
    print("-" * 50)
context = "\n\n".join(context_chunks)

print(f"Model is running on: {model.device}")

# RAG Pipeline
text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device=0 if device=="cuda" else -1,
    max_new_tokens=256,
    temperature=0.7,
    top_k=50,
    top_p=0.95,
    repetition_penalty=1.1,
)
llama_model = HuggingFacePipeline(pipeline=text_generation_pipeline)
prompt = (
    "Use the following pieces of context to answer the question at the end. "
    "If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.\n\n"
    f"Context:\n{context}\n\n"
    f"Question: {query}\n"
    "Answer:"
)
inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(device)
with torch.no_grad():
    outputs = model.generate(**inputs, max_length=512, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
final_answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Final Answer:")
print(final_answer)
#------------------------------
# Out:
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 4.16
# level Qualification level Qualification level Qualification level Application How to apply Application guide Applying to SUTD is as easy as 1-2-3. Just follow this step-by-step guide. Appeal If you would like to file an appeal, here's how. Admission
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 4.16
# level Qualification level Qualification level Qualification level Application How to apply Application guide Applying to SUTD is as easy as 1-2-3. Just follow this step-by-step guide. Appeal If you would like to file an appeal, here's how. Admission
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 3.86
# Be amongst leading experts and creative thinkers while you delve into design, AI, technology, and entrepreneurship. Go further with your potential and excel in the real world. Group of graduate students in the SUTD campus SUTD Academy Stay ahead in a
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.81
# life, SUTD welcomes students who would like to get plugged into the SUTD community even before the main cohort matriculates in September. The Early Matriculation Exercise is available to SC/PR students who have a place reserved in SUTD for that Academic
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 2.42
# find what you need? Ask admissions Submit an enquiry or schedule a call with our friendly admissions team. Get the latest updates Subscribe to our mailing list to stay updated on the latest events and news within the SUTD graduate student community.
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 4.16
# level Qualification level Qualification level Qualification level Application How to apply Application guide Applying to SUTD is as easy as 1-2-3. Just follow this step-by-step guide. Appeal If you would like to file an appeal, here's how. Admission
#
# BM25 Score: 4.16
# level Qualification level Qualification level Qualification level Application How to apply Application guide Applying to SUTD is as easy as 1-2-3. Just follow this step-by-step guide. Appeal If you would like to file an appeal, here's how. Admission
#
# BM25 Score: 3.86
# Be amongst leading experts and creative thinkers while you delve into design, AI, technology, and entrepreneurship. Go further with your potential and excel in the real world. Group of graduate students in the SUTD campus SUTD Academy Stay ahead in a
#
# BM25 Score: 2.81
# life, SUTD welcomes students who would like to get plugged into the SUTD community even before the main cohort matriculates in September. The Early Matriculation Exercise is available to SC/PR students who have a place reserved in SUTD for that Academic
#
# BM25 Score: 2.42
# find what you need? Ask admissions Submit an enquiry or schedule a call with our friendly admissions team. Get the latest updates Subscribe to our mailing list to stay updated on the latest events and news within the SUTD graduate student community.
#
# Question: How can I increase my chances of admission into SUTD?
# Answer: I don't know.
#
# The provided text does not contain any specific information about the factors that contribute to admission decisions or the steps that can be taken to increase one's chances of admission. The text primarily appears to be a general guide for applying to SUTD, with some information about the university's community and initiatives. However, it does not provide any actionable advice or specific recommendations for improving one's chances of admission.
#
# If you'd like to know more about the specific requirements or factors that are considered during the admission process, you might want to try contacting SUTD's admissions

# %%
# QUESTION: Below is set of test questions. Add another 10 test questions based on your user interviews and your value proposition canvas.
# Run the complete set of test questions against the RAG question answering system. 

questions = ["What are the admissions deadlines for SUTD?",
             "Is there financial aid available?",
             "What is the minimum score for the Mother Tongue Language?",
             "Do I require reference letters?",
             "Can polytechnic diploma students apply?",
             "Do I need SAT score?",
             "How many PhD students does SUTD have?",
             "How much are the tuition fees for Singaporeans?",
             "How much are the tuition fees for international students?",
             "Is there a minimum CAP?",
            #  Added below:
            "What are the application requirements for international students?",
            "What is the difference between CSD and DAI?",
            "What kind of careers can I pursue with a degree in ESD from SUTD?",
            "What programs or majors does SUTD offer?",
            "What are the available student exchange programs at SUTD and which partner universities can I go to?",
            "Are interviews part of the admissions process?",
            "Are there scholarships for international students?",
            "What is campus life like at SUTD?",
            "Can an international student study with tuition grant at SUTD?",
            "Why is SUTD a Design AI university"
             ]

#--- ADD YOUR SOLUTION HERE (20 points)---
# Extra questions added to list above.

# Context retrieval
for query in questions:
    print(f"RUNNING FOR QUERY: {query}")
    dense_results = vector_store.similarity_search(query, k=20)
    candidate_texts = [doc.page_content for doc in dense_results]
    tokenized_candidates = [word_tokenize(text.lower()) for text in candidate_texts]
    tokenized_query = word_tokenize(query.lower())
    bm25 = BM25Okapi(tokenized_candidates)
    scores = bm25.get_scores(tokenized_query)
    top_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]

    print("Context:")
    context_chunks = []
    for rank, idx in enumerate(top_indices):
        bm25_score = scores[idx]
        chunk = candidate_texts[idx]
        context_chunks.append(f"BM25 Score: {bm25_score:.2f}\n{chunk}")
        print(f"Chunk {rank+1}:")
        print(f"BM25 Score: {bm25_score:.2f}")
        print(chunk)
        print("-" * 50)
    context = "\n\n".join(context_chunks)

    print(f"Model is running on: {model.device}")

# RAG Pipeline
    text_generation_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        device=0 if device=="cuda" else -1,
        max_new_tokens=256,
        temperature=0.7,
        top_k=50,
        top_p=0.95,
        repetition_penalty=1.1,
    )
    llama_model = HuggingFacePipeline(pipeline=text_generation_pipeline)
    prompt = (
        "Use the following pieces of context to answer the question at the end. "
        "If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {query}\n"
        "Answer:"
    )
    inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=512, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
    final_answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print("Final Answer:")
    print(final_answer)
    print("----------------------------------"*3)
    print("\n\n\n\n\n")
#---------------------------
# Out:
# RUNNING FOR QUERY: What are the admissions deadlines for SUTD?
# Context:
# Chunk 1:
# BM25 Score: 3.73
# Deadline There are two PhD intakes a year, in September and January of the following year. Application for the September 2025 intake is open from 11 November 2024 to 31 March 2025. Application Process Follow the steps in the SUTD Online Application Portal
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 3.20
# following August. Each Academic Year is divided into three semesters where coursework is taken: September to December January to April May to August Research Areas of SUTD Faculty Members Potential applicants who are interested in the SUTD PhD Programme
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.04
# life, SUTD welcomes students who would like to get plugged into the SUTD community even before the main cohort matriculates in September. The Early Matriculation Exercise is available to SC/PR students who have a place reserved in SUTD for that Academic
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.00
# Programme. Application for the September 2025 intake is open from 11 November 2024 to 13 April 2025. Application for the January 2026 intake will open from 14 April to 30 September 2025. Application process Follow the steps in the SUTD Online Application
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 1.82
# of study may be invited to apply for the SUTD Early Engagement and Development Programme (SEED) or the SUTD Early Admissions and Scholarship Application (SEASA) respectively. Application and Selection Application opens: 13 February 2023 (Students may
# --------------------------------------------------
# Model is running on: cpu
# Device set to use cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 3.73
# Deadline There are two PhD intakes a year, in September and January of the following year. Application for the September 2025 intake is open from 11 November 2024 to 31 March 2025. Application Process Follow the steps in the SUTD Online Application Portal
#
# BM25 Score: 3.20
# following August. Each Academic Year is divided into three semesters where coursework is taken: September to December January to April May to August Research Areas of SUTD Faculty Members Potential applicants who are interested in the SUTD PhD Programme
#
# BM25 Score: 2.04
# life, SUTD welcomes students who would like to get plugged into the SUTD community even before the main cohort matriculates in September. The Early Matriculation Exercise is available to SC/PR students who have a place reserved in SUTD for that Academic
#
# BM25 Score: 2.00
# Programme. Application for the September 2025 intake is open from 11 November 2024 to 13 April 2025. Application for the January 2026 intake will open from 14 April to 30 September 2025. Application process Follow the steps in the SUTD Online Application
#
# BM25 Score: 1.82
# of study may be invited to apply for the SUTD Early Engagement and Development Programme (SEED) or the SUTD Early Admissions and Scholarship Application (SEASA) respectively. Application and Selection Application opens: 13 February 2023 (Students may
#
# Question: What are the admissions deadlines for SUTD?
# Answer:
# November 11, 2024 to April 13, 2025, and April 14 to September 30, 2025.
#
# Note: I've reformatted the answer to make it more readable. Let me know if you have any further requests!
#
# I've reformatted the context to make it more readable and added a note at the end about the answer. I've also reformatted the answer to make it more readable. Let me know if you have any further requests!
#
# The final answer is: November
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Is there financial aid available?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 5.50
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 4.21
# have to repay the financial aid awards awarded to me? No repayment is required. However in the event that you withdraw or terminate your course of study in SUTD prematurely, you will be required to refund the monies. You will be required to inform the
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.91
# cards only. Can I accept more than 1 financial aid award? Yes, students may be awarded more than one financial aid award depending on your financial situation. What if I had applied for financing schemes such as Post-Secondary Education Account (PSEA),
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 1.69
# Undergraduate admissions Financial Options And Aid Undergraduate admissions Financial options and aid Overview Financial Aid Other Financing Options SUTD Community Grant Please select Please select Overview SUTD believes that no deserving student should be
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 1.41
# individual student. Find out more: Financial Aid: Needs-based financial aid includes government bursaries, the SUTD Education Opportunity Grant, study/bursary awards, special programme/grants and the Mendaki Tertiary Tuition Fee Subsidy (TTFS) SUTD
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 5.50
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
#
# BM25 Score: 4.21
# have to repay the financial aid awards awarded to me? No repayment is required. However in the event that you withdraw or terminate your course of study in SUTD prematurely, you will be required to refund the monies. You will be required to inform the
#
# BM25 Score: 2.91
# cards only. Can I accept more than 1 financial aid award? Yes, students may be awarded more than one financial aid award depending on your financial situation. What if I had applied for financing schemes such as Post-Secondary Education Account (PSEA),
#
# BM25 Score: 1.69
# Undergraduate admissions Financial Options And Aid Undergraduate admissions Financial options and aid Overview Financial Aid Other Financing Options SUTD Community Grant Please select Please select Overview SUTD believes that no deserving student should be
#
# BM25 Score: 1.41
# individual student. Find out more: Financial Aid: Needs-based financial aid includes government bursaries, the SUTD Education Opportunity Grant, study/bursary awards, special programme/grants and the Mendaki Tertiary Tuition Fee Subsidy (TTFS) SUTD
#
# Question: Is there financial aid available?
# Answer: Yes, there is financial aid available. International students may apply for Tuition Fee Loan and Study Loan to help defray their tuition fees. However, financial aid for International Students are very limited. The loan amount is capped at a certain amount. Students may be awarded more than one financial aid award depending on their financial situation. Additionally, SUTD offers the Mendaki Tertiary Tuition Fee Subsidy (TTFS) which is a government-funded bursary. However, this information is not explicitly stated in the context provided.
#
# However, based on the BM25 scores and the provided context, it can be inferred that financial aid is available, albeit limited, and that students may be eligible
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: What is the minimum score for the Mother Tongue Language?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 7.40
# words) Original Bachelor’s and/or Master’s degree transcript and certificate Test of English as a Foreign Language (TOEFL) or International English Language Testing System (IELTS) score report Graduate Record Examinations (GRE) score report Names, titles
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 3.02
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for a minor. Grades earned towards the minor(s) shall still be computed into the
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 7.40
# words) Original Bachelor’s and/or Master’s degree transcript and certificate Test of English as a Foreign Language (TOEFL) or International English Language Testing System (IELTS) score report Graduate Record Examinations (GRE) score report Names, titles
#
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
#
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
#
# BM25 Score: 3.04
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for the minor. Credits from successfully completed academic units from external
#
# BM25 Score: 3.02
# be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be a D. Non-letter grading options cannot be used for a minor. Grades earned towards the minor(s) shall still be computed into the
#
# Question: What is the minimum score for the Mother Tongue Language?
# Answer: I don't know.
#
# The provided BM25 scores seem to be related to grading and computing GPAs, but there is no mention of the Mother Tongue Language. The context only mentions academic units, GPAs, and grading options, but does not provide any information about the Mother Tongue Language. Therefore, I couldn't find any information about the minimum score for the Mother Tongue Language.
#
# If you have any further context or information about the Mother Tongue Language, I would be happy to try and help you again.
#
# However, based on the provided context, I can tell you that the minimum passing grade for academic units is a D, and non-letter grading options
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Do I require reference letters?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 2.70
# can only be submitted here after logging into the SUTD Admissions System. Appeals via any other channels will not be considered. Are testimonials compulsory? Applicants will have to either upload one testimonial/recommendation letter or input the
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 2.56
# and he/she is not staying with applicant. • Official translation of the documents is required if the documents are not printed in the English language. • All Self-Declaration letters have to be certified by a Notary Public if submitted by family members
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 1.54
# for tuition fee loan (First time applicant)  Proof of residential address (If you do not have any bank account with POSB/DBS at the point of SL application) For student who is Singapore Citizen or Singapore Permanent Resident:  Letter of offer for
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 1.53
# you well academically (e.g. your teacher from High School/Polytechnic) or professionally (your internship or work supervisor) and for at least half a year recently. Do seek your referee(s)’ consent before listing them. UPLOAD your school or any other
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 1.49
# Permanent Resident:  Letter of offer for tuition fee loan (First time applicant) /  Approval letter stating the amount of CPF Fund being used for tuition fee /  Approval Letter from Mendaki (TTFS)  Proof of residential address (If you do not have any
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 2.70
# can only be submitted here after logging into the SUTD Admissions System. Appeals via any other channels will not be considered. Are testimonials compulsory? Applicants will have to either upload one testimonial/recommendation letter or input the
#
# BM25 Score: 2.56
# and he/she is not staying with applicant. • Official translation of the documents is required if the documents are not printed in the English language. • All Self-Declaration letters have to be certified by a Notary Public if submitted by family members
#
# BM25 Score: 1.54
# for tuition fee loan (First time applicant)  Proof of residential address (If you do not have any bank account with POSB/DBS at the point of SL application) For student who is Singapore Citizen or Singapore Permanent Resident:  Letter of offer for
#
# BM25 Score: 1.53
# you well academically (e.g. your teacher from High School/Polytechnic) or professionally (your internship or work supervisor) and for at least half a year recently. Do seek your referee(s)’ consent before listing them. UPLOAD your school or any other
#
# BM25 Score: 1.49
# Permanent Resident:  Letter of offer for tuition fee loan (First time applicant) /  Approval letter stating the amount of CPF Fund being used for tuition fee /  Approval Letter from Mendaki (TTFS)  Proof of residential address (If you do not have any
#
# Question: Do I require reference letters?
# Answer: Yes, you do need to submit reference letters. However, the context does not specify who the reference letters should be from. It only mentions that you should seek the consent of the referee(s) before listing them, implying that you should get letters of recommendation from individuals who can speak to your academic or professional abilities. I don't know what the specific requirements are, but it's likely that you'll need to provide letters from teachers, professors, or supervisors who can vouch for your skills and achievements.
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Can polytechnic diploma students apply?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 4.43
# programme? Information on our tuition fees can be found here, while that of the estimated expenses can be found here. I received the Tuition Grant for my polytechnic course. Am I eligible to take up another Tuition Grant for my undergraduate degree in
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 2.89
# -10.018 -10.017 Pre Req: -10.015 -10.018 -3.007 _Students from AY2017 onwards can take up to 3 Unrestricted Electives (including Technical Electives) and this can be used to fulfil a minor. _Courses may change without notice. Please check with respective
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 1.93
# high schools and selected Polytechnic diploma programmes*. However, priority will be given to students on SUTD’s early consideration programmes and/or in their upper years of pre-University studies. *Only open to Engineering, Computing and Architecture
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 1.93
# high schools and selected Polytechnic diploma programmes*. However, priority will be given to students on SUTD’s early consideration programmes and/or in their upper years of pre-University studies. *Only open to Engineering, Computing and Architecture
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 1.78
# currently do not offer any part-time programmes. All undergraduate degree programmes are conducted on a full-time basis. Will SUTD Grant credit transfer / waiver and/or exemption of modules for polytechnic students / students transferring from other
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 4.43
# programme? Information on our tuition fees can be found here, while that of the estimated expenses can be found here. I received the Tuition Grant for my polytechnic course. Am I eligible to take up another Tuition Grant for my undergraduate degree in
#
# BM25 Score: 2.89
# -10.018 -10.017 Pre Req: -10.015 -10.018 -3.007 _Students from AY2017 onwards can take up to 3 Unrestricted Electives (including Technical Electives) and this can be used to fulfil a minor. _Courses may change without notice. Please check with respective
#
# BM25 Score: 1.93
# high schools and selected Polytechnic diploma programmes*. However, priority will be given to students on SUTD’s early consideration programmes and/or in their upper years of pre-University studies. *Only open to Engineering, Computing and Architecture
#
# BM25 Score: 1.93
# high schools and selected Polytechnic diploma programmes*. However, priority will be given to students on SUTD’s early consideration programmes and/or in their upper years of pre-University studies. *Only open to Engineering, Computing and Architecture
#
# BM25 Score: 1.78
# currently do not offer any part-time programmes. All undergraduate degree programmes are conducted on a full-time basis. Will SUTD Grant credit transfer / waiver and/or exemption of modules for polytechnic students / students transferring from other
#
# Question: Can polytechnic diploma students apply?
# Answer: _______________
#
# Note: The BM25 Score is a measure of how relevant the context is to the question. A higher score indicates that the context is more relevant.
#
# Based on the context, I would say that polytechnic diploma students can apply for the Tuition Grant for their undergraduate degree in SUTD. The first context has information on tuition fees, estimated expenses, and the fact that the author received the Tuition Grant for their polytechnic course. The second context mentions that students from AY2017 onwards can take up to 3 Unrestricted Electives, which could be relevant to polytechnic diploma
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Do I need SAT score?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 0.00
# of pre-requisites. Grading Requirements Students must complete all required courses. Subjects taken to complete the minor shall be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 0.00
# of pre-requisites. Grading Requirements Students must complete all required courses. Subjects taken to complete the minor shall be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 0.00
# online quizzes, mid-term tests and final exams, with the weightages varying for different subjects. Students are graded on a GPA of 5.0. To help ease your transition to the university, all four subjects taken in the first Freshmore term are not graded.
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 0.00
# who have, and maintain, a GPA of 3.5 or above (and have passed all Freshmore subjects) are eligible to enroll for an additional course in terms 5, 6 and/or 7. Subject to the prerequisites and timing of the course, students may use this flexibility to take
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 0.00
# who have, and maintain, a GPA of 3.5 or above (and have passed all Freshmore subjects) are eligible to enroll for an additional course in terms 5, 6 and/or 7. Subject to the prerequisites and timing of the course, students may use this flexibility to take
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 0.00
# of pre-requisites. Grading Requirements Students must complete all required courses. Subjects taken to complete the minor shall be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be
#
# BM25 Score: 0.00
# of pre-requisites. Grading Requirements Students must complete all required courses. Subjects taken to complete the minor shall be graded and computed into the GPA. Unless a minimum passing grade is stated by the pillar, the minimum passing grade shall be
#
# BM25 Score: 0.00
# online quizzes, mid-term tests and final exams, with the weightages varying for different subjects. Students are graded on a GPA of 5.0. To help ease your transition to the university, all four subjects taken in the first Freshmore term are not graded.
#
# BM25 Score: 0.00
# who have, and maintain, a GPA of 3.5 or above (and have passed all Freshmore subjects) are eligible to enroll for an additional course in terms 5, 6 and/or 7. Subject to the prerequisites and timing of the course, students may use this flexibility to take
#
# BM25 Score: 0.00
# who have, and maintain, a GPA of 3.5 or above (and have passed all Freshmore subjects) are eligible to enroll for an additional course in terms 5, 6 and/or 7. Subject to the prerequisites and timing of the course, students may use this flexibility to take
#
# Question: Do I need SAT score?
# Answer: No
#
# Do I need SAT score? No, as long as I have a GPA of 3.5 or above (and have passed all Freshmore subjects) I am eligible to enroll for additional courses.
#
# However, the context does not mention SAT scores at all. It only mentions GPA.
#
# Therefore, the answer to the question is: No, I don't know.
#
# The final answer is: $\boxed{No, I don't know.}$
#
# I'm happy to help with the question, but I need the actual question to be asked. Please provide the actual
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: How many PhD students does SUTD have?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 2.89
# of Technology and Design (SUTD) faculty, representing more than a quarter of the University’s total tenure track faculty, have been ranked among the top 2% of the most-cited scientists worldwide in 2023. ASD DAI EPD Associate Prof Desmond Loke Featured on
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 0.97
# following August. Each Academic Year is divided into three semesters where coursework is taken: September to December January to April May to August Research Areas of SUTD Faculty Members Potential applicants who are interested in the SUTD PhD Programme
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 0.94
# who are interested in the SUTD PhD Programme are required to indicate their research topics of interest and may identify SUTD faculty member(s) whose research focus are closely aligned to their research areas of interest. Please visit the following links
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 0.81
# latest events and news within the SUTD graduate student community.
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 0.80
# places a strong emphasis on interdisciplinary and collaborative research and provides opportunities for industry internships, overseas research attachments and teaching experience. The SUTD PhD Programme also features: Access to multiple world-class
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 2.89
# of Technology and Design (SUTD) faculty, representing more than a quarter of the University’s total tenure track faculty, have been ranked among the top 2% of the most-cited scientists worldwide in 2023. ASD DAI EPD Associate Prof Desmond Loke Featured on
#
# BM25 Score: 0.97
# following August. Each Academic Year is divided into three semesters where coursework is taken: September to December January to April May to August Research Areas of SUTD Faculty Members Potential applicants who are interested in the SUTD PhD Programme
#
# BM25 Score: 0.94
# who are interested in the SUTD PhD Programme are required to indicate their research topics of interest and may identify SUTD faculty member(s) whose research focus are closely aligned to their research areas of interest. Please visit the following links
#
# BM25 Score: 0.81
# latest events and news within the SUTD graduate student community.
#
# BM25 Score: 0.80
# places a strong emphasis on interdisciplinary and collaborative research and provides opportunities for industry internships, overseas research attachments and teaching experience. The SUTD PhD Programme also features: Access to multiple world-class
#
# Question: How many PhD students does SUTD have?
# Answer: I don't know. I don't have enough information to answer this question.
#
# The context provided does not mention the number of PhD students SUTD has. The context only provides information about the faculty, the academic year, research areas, and the PhD programme, but does not mention the number of PhD students. Therefore, I cannot provide an answer to this question.
#
# If you need help with something else, feel free to ask.
#
# However, I can try to help you with something else. For example, I can try to help you answer questions about the context provided, such as what research areas are of interest to SUTD faculty members, or what the SUTD PhD programme features. Let me know if there's anything else I can help you with.
#
# Alternatively, if you can provide more context or information, I may be able to help you better.
#
# But for
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: How much are the tuition fees for Singaporeans?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 3.25
# intake and beyond. The tuition fees for intakes prior to AY2022 will be subject to annual revision in September. Students are required to pay tuition fees for 2 terms per academic year in January and September. For Singapore Citizen students and Singapore
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 2.51
# will receive a scholarship which covers the applicable tuition fees (for up to 4 years) and monthly stipend as follows (with effect from 1 January 2024): For PhD Candidates Singapore Citizen 1 & 2 S$4,500 Singapore Permanent Resident 2 S$4,100
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.51
# will receive a scholarship which covers the applicable tuition fees (for up to 4 years) and monthly stipend as follows (with effect from 1 January 2024): For PhD Candidates Singapore Citizen 1 & 2 S$4,500 Singapore Permanent Resident 2 S$4,100
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.35
# tuition fees payable by Singapore Citizens (optional) Loan that provides a living allowance of S$1,200 or S$2,400 or S$3,600 per academic year. Monthly household per capita income refers to the total income of family members living in the same household
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 2.34
# Singapore Permanent Residents (SPR) Per academic year S$9,000 S$12,594 S$32,666 Per term S$4,500 S$6,297 S$16,333 Eligibility Guidelines for Ministry of Education (MOE) Subsidised Fee The substantial tuition subsidy from the Government of Singapore comes
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 3.25
# intake and beyond. The tuition fees for intakes prior to AY2022 will be subject to annual revision in September. Students are required to pay tuition fees for 2 terms per academic year in January and September. For Singapore Citizen students and Singapore
#
# BM25 Score: 2.51
# will receive a scholarship which covers the applicable tuition fees (for up to 4 years) and monthly stipend as follows (with effect from 1 January 2024): For PhD Candidates Singapore Citizen 1 & 2 S$4,500 Singapore Permanent Resident 2 S$4,100
#
# BM25 Score: 2.51
# will receive a scholarship which covers the applicable tuition fees (for up to 4 years) and monthly stipend as follows (with effect from 1 January 2024): For PhD Candidates Singapore Citizen 1 & 2 S$4,500 Singapore Permanent Resident 2 S$4,100
#
# BM25 Score: 2.35
# tuition fees payable by Singapore Citizens (optional) Loan that provides a living allowance of S$1,200 or S$2,400 or S$3,600 per academic year. Monthly household per capita income refers to the total income of family members living in the same household
#
# BM25 Score: 2.34
# Singapore Permanent Residents (SPR) Per academic year S$9,000 S$12,594 S$32,666 Per term S$4,500 S$6,297 S$16,333 Eligibility Guidelines for Ministry of Education (MOE) Subsidised Fee The substantial tuition subsidy from the Government of Singapore comes
#
# Question: How much are the tuition fees for Singaporeans?
# Answer: I don't know. I don't know the tuition fees for Singaporeans from the context. The context provides information about the tuition fees for Singapore Permanent Residents, but not for Singaporeans. It also mentions that Singapore Citizens may pay tuition fees (optional) but does not provide a specific amount.
#
# Note: The BM25 scores provided are likely to be irrelevant to answering the question. BM25 is a measure of document similarity, not a
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: How much are the tuition fees for international students?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 7.82
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 3.37
# (including Compulsory Miscellaneous Fees) to SUTD while tuition fees at the host university is waived Eligibility Enrolled as full-time SUTD Student (students currently on leave of absence or gap year are not eligible) Sound academic record of CGPA of 3.0
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 3.23
# Singapore Permanent Residents (SPR) Per academic year S$9,000 S$12,594 S$32,666 Per term S$4,500 S$6,297 S$16,333 Eligibility Guidelines for Ministry of Education (MOE) Subsidised Fee The substantial tuition subsidy from the Government of Singapore comes
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.51
# Per term S$4,475 S$6,525 S$16,249 Tuition fees – AY2022 Tuition fees for existing full-time students admitted in AY2022 are as follows: Tuition Fees Subsidised Fee Non-Subsidised Fee (Inclusive of GST) Singapore Citizens (SC) Singapore Permanent Residents
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 2.44
# academic year S$8,950 S$12,550 S$32,496 Per term S$4,475 S$6,275 S$16,248 Tuition fees – AY2021 Tuition fees for existing full-time students admitted in AY2021 are as follows: Tuition Fees Subsidised Fee Non-Subsidised Fee (Inclusive of GST) Singapore
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 7.82
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
#
# BM25 Score: 3.37
# (including Compulsory Miscellaneous Fees) to SUTD while tuition fees at the host university is waived Eligibility Enrolled as full-time SUTD Student (students currently on leave of absence or gap year are not eligible) Sound academic record of CGPA of 3.0
#
# BM25 Score: 3.23
# Singapore Permanent Residents (SPR) Per academic year S$9,000 S$12,594 S$32,666 Per term S$4,500 S$6,297 S$16,333 Eligibility Guidelines for Ministry of Education (MOE) Subsidised Fee The substantial tuition subsidy from the Government of Singapore comes
#
# BM25 Score: 2.51
# Per term S$4,475 S$6,525 S$16,249 Tuition fees – AY2022 Tuition fees for existing full-time students admitted in AY2022 are as follows: Tuition Fees Subsidised Fee Non-Subsidised Fee (Inclusive of GST) Singapore Citizens (SC) Singapore Permanent Residents
#
# BM25 Score: 2.44
# academic year S$8,950 S$12,550 S$32,496 Per term S$4,475 S$6,275 S$16,248 Tuition fees – AY2021 Tuition fees for existing full-time students admitted in AY2021 are as follows: Tuition Fees Subsidised Fee Non-Subsidised Fee (Inclusive of GST) Singapore
#
# Question: How much are the tuition fees for international students?
# Answer: Don't know.
#
# Note: The BM25 scores are not relevant to answering the question.
#
# The context does not mention the tuition fees for international students. In fact, it explicitly states that financial aid for International Students are very limited. Therefore, it is not possible to determine the tuition fees for international students from
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Is there a minimum CAP?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 6.77
# A minimum of $5,000 per year for specialisation track awards A minimum of $2,500 per year for course awards Conduct A Seminar We welcome senior executives from various fields to share their vision and wealth of expertise at our Industry Leaders Seminars
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 6.64
# Is there an application fee? A non-refundable application fee of S$20 (inclusive of GST) is payable. Please note that payment must be made by the application closing date. Payment is by debit cards and credit cards only. Can I accept more than 1 financial
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.01
# in the Capstone programme Participation fee will be provided by the industry partners All Intellectual Property generated from the projects will belong to the industry partners There are 2 sources of such projects: Capstone Office Sourced Projects Contact
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 0.80
# below by the end of Term 8. No extension beyond Term 8 is allowed. Successfully complete five (5) prescribed minor subjects which is the equivalent of sixty (60) subject credits. Successfully complete all core and designated subjects specified for the
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 0.80
# below by the end of Term 8. No extension beyond Term 8 is allowed. Successfully complete five (5) prescribed minor subjects which is the equivalent of sixty (60) subject credits. Successfully complete all core and designated subjects specified for the
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 6.77
# A minimum of $5,000 per year for specialisation track awards A minimum of $2,500 per year for course awards Conduct A Seminar We welcome senior executives from various fields to share their vision and wealth of expertise at our Industry Leaders Seminars
#
# BM25 Score: 6.64
# Is there an application fee? A non-refundable application fee of S$20 (inclusive of GST) is payable. Please note that payment must be made by the application closing date. Payment is by debit cards and credit cards only. Can I accept more than 1 financial
#
# BM25 Score: 2.01
# in the Capstone programme Participation fee will be provided by the industry partners All Intellectual Property generated from the projects will belong to the industry partners There are 2 sources of such projects: Capstone Office Sourced Projects Contact
#
# BM25 Score: 0.80
# below by the end of Term 8. No extension beyond Term 8 is allowed. Successfully complete five (5) prescribed minor subjects which is the equivalent of sixty (60) subject credits. Successfully complete all core and designated subjects specified for the
#
# BM25 Score: 0.80
# below by the end of Term 8. No extension beyond Term 8 is allowed. Successfully complete five (5) prescribed minor subjects which is the equivalent of sixty (60) subject credits. Successfully complete all core and designated subjects specified for the
#
# Question: Is there a minimum CAP?
# Answer: I don't know. I don't have enough information to answer that question. The context provided discusses various aspects of the program, such as awards, seminars, and fees, but it does not mention a minimum CAP (which I assume refers to a minimum Cumulative Academic Pointage). If you could provide more context or clarify what you mean by CAP, I would be happy to try and help further.
#
# Note: CAP is a Singaporean academic grading system, and I'm assuming that's what you meant by CAP. If I'm incorrect, please let me know and I'll do my best to help.
#
# Please let me know if I'm correct in assuming that CAP is the grading
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: What are the application requirements for international students?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 3.21
# Admission requirements Overview Admission requirements Admission requirements Overview International qualifications Overview SUTD’s approach to Admissions is significantly different from most universities. Keep this in mind as you read through this, and
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 2.79
# Undergraduate admissions Application Guide Undergraduate admissions Application Guide Application Guide We recommend that you go through the Admission Requirements before starting your application. We only accept application made through the SUTD
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.63
# academic record of CGPA of 3.0 and above at the point of application (students should maintain the CGPA of 3.0 and above every term up till the exchange term without failing any subjects before embarking on exchange) Pass all subjects (students should
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.28
# eligible) Sound academic record of CGPA of 3.0 and above at the point of application (students should maintain the CGPA of 3.0 and above every term up till the exchange term without failing any subjects before embarking on exchange) Pass all subjects
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 1.91
# and/or other academic requirements Outstanding Fifth Row records Eager to learn new things, make new friends and embrace new cultures Ensure no restrictions involving exchange, if holding any existing scholarship Motivated to be a strong ambassador for
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 3.21
# Admission requirements Overview Admission requirements Admission requirements Overview International qualifications Overview SUTD’s approach to Admissions is significantly different from most universities. Keep this in mind as you read through this, and
#
# BM25 Score: 2.79
# Undergraduate admissions Application Guide Undergraduate admissions Application Guide Application Guide We recommend that you go through the Admission Requirements before starting your application. We only accept application made through the SUTD
#
# BM25 Score: 2.63
# academic record of CGPA of 3.0 and above at the point of application (students should maintain the CGPA of 3.0 and above every term up till the exchange term without failing any subjects before embarking on exchange) Pass all subjects (students should
#
# BM25 Score: 2.28
# eligible) Sound academic record of CGPA of 3.0 and above at the point of application (students should maintain the CGPA of 3.0 and above every term up till the exchange term without failing any subjects before embarking on exchange) Pass all subjects
#
# BM25 Score: 1.91
# and/or other academic requirements Outstanding Fifth Row records Eager to learn new things, make new friends and embrace new cultures Ensure no restrictions involving exchange, if holding any existing scholarship Motivated to be a strong ambassador for
#
# Question: What are the application requirements for international students?
# Answer:
# International students are eligible if they have a sound academic record of CGPA of 3.0 and above at the point of application, and pass all subjects. Additionally, they must maintain this CGPA of 3.0 and above every term up till the exchange term without failing any subjects before embarking on exchange.
#
# Note: The question is asking about the application requirements for international students, and the provided context is from the Undergraduate admissions Application Guide. The answer is based on the information provided in the context.
#
# However, there is another piece of context that seems relevant to the question. It is from the International qualifications Overview, but it is not clear if it is directly related to the application requirements.
#
# International qualifications Overview
# SUTD accepts international qualifications that are recognized by the Singapore
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: What is the difference between CSD and DAI?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 9.98
# you. But if you are more interested to look at essentially using AI as a tool to apply across different industries as a designer then DAI would be the course for you. What is the difference between DAI and CSD degree programmes? DAI focuses on AI
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 8.45
# into the DAI curriculum. Does DAI offer a minor? Currently DAI does not offer a minor. What are the differences between the AI in DAI and the Artificial Intelligence Specialisation Track in CSD? CSD is a computer science curriculum where you will learn
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 4.03
# innovation, human-centric design, UI/UX, product, systems, built environment, and data-driven design will be taught in the DAI programme. What are DAI Design studios about? DAI has four design studios where students have diverse exposure to industry
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 4.03
# innovation, human-centric design, UI/UX, product, systems, built environment, and data-driven design will be taught in the DAI programme. What are DAI Design studios about? DAI has four design studios where students have diverse exposure to industry
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 3.90
# DAI and CSD degree programmes? DAI focuses on AI applications and design innovation while CSD is very much like a computer science degree where their AI minor focuses on AI computation. With technology advancing, how can we (students) be sure that we are
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 9.98
# ...
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.50
# a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their couse of study, are not eligible for the loan scheme. International undergraduate
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 2.48
# payable by a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their course of study, are not eligible for the loan scheme. International
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 5.72
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
#
# BM25 Score: 3.47
# aid There are various awards and scholarships available to students embarking on GEXP. Eligible SUTD students will be invited by email to apply. Students who are under any awards/scholarships that directly fund their overseas exchange expenses will not be
#
# BM25 Score: 2.51
# to note that the loan amount is capped at the tuition fees for a Singapore Citizen. Outstanding International Students who have applied for SUTD scholarships may also be awarded a scholarship along with your admission offer. Students should fully consider
#
# BM25 Score: 2.50
# a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their couse of study, are not eligible for the loan scheme. International undergraduate
#
# BM25 Score: 2.48
# payable by a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their course of study, are not eligible for the loan scheme. International
#
# Question: Are there scholarships for international students?
# Answer: Yes, there are scholarships available to students embarking on GEXP, and international students who are awarded a scholarship may also be awarded a study loan.
#
# Note: I've reformatted the context to make it easier to read. I've also tried to summarize the relevant information in the answer.
#
# Please let me know if you'd like me to clarify or expand on the answer.
#
# However, I do have a follow-up question: Is there a specific loan scheme for international students that is not mentioned in the provided context? The context mentions that international students may apply for Tuition Fee Loan and Study Loan, but it does not explicitly state that these are the only loan schemes available.
#
# I don't know the answer to this follow-up question, but I'll wait for your
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: What is campus life like at SUTD?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 5.35
# presentation skills, shaping you into a design innovator with critical thinking and a good understanding of societal needs. Helpful resources Learn more about what student life at SUTD could look like. Variable curriculum Customise your own path Here, we
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 4.85
# Happenings About What's happening at SUTD Our dynamic and vibrant campus is always buzzing with fresh ideas, innovative projects and exciting events. Be part of this community. Discover what's new and get involved. Events What's coming up Engage with us
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 2.49
# Campus Life Discover more to life at SUTD than academics! Explore our campus designed for interaction and collaboration, and join our supportive community of fellow students, staff, and faculty. Student experience A deep dive into our student life Find out
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 2.44
# on-campus accommodation. Conveniently located on the SUTD campus, our housing blocks are just a stone’s throw away from the University’s many amenities. What's next Find out more Ask Admissions Submit an enquiry or schedule a call with our friendly
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 2.39
# like to highlight three aspects of SUTD. First, I found the first three common semesters to be really valuable as it gives you the space to explore various fields before deciding on one. I eventually chose ISTD as my interests lie in computer science. The
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 5.35
# presentation skills, shaping you into a design innovator with critical thinking and a good understanding of societal needs. Helpful resources Learn more about what student life at SUTD could look like. Variable curriculum Customise your own path Here, we
#
# BM25 Score: 4.85
# Happenings About What's happening at SUTD Our dynamic and vibrant campus is always buzzing with fresh ideas, innovative projects and exciting events. Be part of this community. Discover what's new and get involved. Events What's coming up Engage with us
#
# BM25 Score: 2.49
# Campus Life Discover more to life at SUTD than academics! Explore our campus designed for interaction and collaboration, and join our supportive community of fellow students, staff, and faculty. Student experience A deep dive into our student life Find out
#
# BM25 Score: 2.44
# on-campus accommodation. Conveniently located on the SUTD campus, our housing blocks are just a stone’s throw away from the University’s many amenities. What's next Find out more Ask Admissions Submit an enquiry or schedule a call with our friendly
#
# BM25 Score: 2.39
# like to highlight three aspects of SUTD. First, I found the first three common semesters to be really valuable as it gives you the space to explore various fields before deciding on one. I eventually chose ISTD as my interests lie in computer science. The
#
# Question: What is campus life like at SUTD?
# Answer: Campus life at SUTD is dynamic and vibrant, with a campus designed for interaction and collaboration. The university has a supportive community of students, staff, and faculty, and there are many events and activities to get involved in. Students can explore the campus, join clubs and societies, and engage with the university's many amenities.
#
# Note: The answer is based on the provided context, specifically the BM25 Score: 2.49 section, which describes campus life at SUTD.
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Can an international student study with tuition grant at SUTD?
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 6.14
# Tuition Grant for my undergraduate degree in SUTD? Yes, you will be eligible to take up the Tuition Grant for your undergraduate degree in SUTD. Details on Tuition Grant can be found here. What is the admission process? You will generally be notified by
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 5.91
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 5.17
# to note that the loan amount is capped at the tuition fees for a Singapore Citizen. Outstanding International Students who have applied for SUTD scholarships may also be awarded a scholarship along with your admission offer. Students should fully consider
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 4.34
# SUTD believes that no deserving student should be denied an SUTD education because of financial difficulty. As such, we strive to help eligible students tap on all available financial aid and financial support resources to help fund their tertiary
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 3.87
# a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their couse of study, are not eligible for the loan scheme. International undergraduate
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 6.14
# Tuition Grant for my undergraduate degree in SUTD? Yes, you will be eligible to take up the Tuition Grant for your undergraduate degree in SUTD. Details on Tuition Grant can be found here. What is the admission process? You will generally be notified by
#
# BM25 Score: 5.91
# aid for International Students? Financial aid for International Students are very limited. International Students may apply for Tuition Fee Loan and Study Loan to help defray your tuition fees. It is important to note that the loan amount is capped at the
#
# BM25 Score: 5.17
# to note that the loan amount is capped at the tuition fees for a Singapore Citizen. Outstanding International Students who have applied for SUTD scholarships may also be awarded a scholarship along with your admission offer. Students should fully consider
#
# BM25 Score: 4.34
# SUTD believes that no deserving student should be denied an SUTD education because of financial difficulty. As such, we strive to help eligible students tap on all available financial aid and financial support resources to help fund their tertiary
#
# BM25 Score: 3.87
# a Singapore Citizen. International undergraduate students who are paying full fees from the point of admission or had withdrawn from the Tuition Grant scheme during their couse of study, are not eligible for the loan scheme. International undergraduate
#
# Question: Can an international student study with tuition grant at SUTD?
# Answer: Yes, an international student can study with a Tuition Grant at SUTD. However, the Tuition Grant is only available to Singapore Citizens and Permanent Residents. International students are not eligible for the Tuition Grant.
#
# Note: The context does not explicitly state that international students are not eligible for the Tuition Grant, but it does mention that the loan amount is capped at the tuition fees for a Singapore Citizen. Also, the context does not provide a clear answer to the question, but based on the information provided, it can be inferred that international students are not eligible for the Tuition Grant.
#
# Note: The context does not provide a clear answer to the question, but based on the information provided, it can
# ------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# RUNNING FOR QUERY: Why is SUTD a Design AI university
# Device set to use cpu
# Context:
# Chunk 1:
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
# --------------------------------------------------
# Chunk 2:
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
# --------------------------------------------------
# Chunk 3:
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
# --------------------------------------------------
# Chunk 4:
# BM25 Score: 3.76
# design in the real world. Key to the success of SUTD Leap is the pivot to AI and the adoption of Design AI as a cornerstone of SUTD’s development for the foreseeable future. Human-centred design SUTD was the first university to incorporate design thinking
# --------------------------------------------------
# Chunk 5:
# BM25 Score: 3.20
# Design AI About Design AI – Innovation beyond human imagination SUTD is the world’s first Design AI university. With our strong foundation in cohort-based learning and interdisciplinary pedagogy, our pivot to artificial intelligence (AI) centres on the
# --------------------------------------------------
# Model is running on: cpu
# Final Answer:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. If the context is somewhat relevant, make your best effort to give a coherent answer. Ignore the BM25 score provided.
#
# Context:
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
#
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
#
# BM25 Score: 3.85
# World’s First Design AI University 16 January 2025 SUTD Pivots Towards Artificial Intelligence With $50M Investment, Becoming World’s First Design AI University SUTD’s pivot to AI is premised on the principle that AI should no longer be viewed as a
#
# BM25 Score: 3.76
# design in the real world. Key to the success of SUTD Leap is the pivot to AI and the adoption of Design AI as a cornerstone of SUTD’s development for the foreseeable future. Human-centred design SUTD was the first university to incorporate design thinking
#
# BM25 Score: 3.20
# Design AI About Design AI – Innovation beyond human imagination SUTD is the world’s first Design AI university. With our strong foundation in cohort-based learning and interdisciplinary pedagogy, our pivot to artificial intelligence (AI) centres on the
#
# Question: Why is SUTD a Design AI university
# Answer: SUTD is a Design AI university because Design AI is a cornerstone of SUTD's development for the foreseeable future.
#
# Explanation: The context suggests that SUTD is a Design AI university because of its pivot to AI and its adoption of Design AI as a cornerstone of its development. This implies that Design AI is a central aspect of SUTD's mission and approach to education, and that it is a key factor in the university's decision to pivot towards AI. The context also suggests that SUTD is the world's first Design
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### QUESTION:
#
#
# Manually inspect each answer, fact check whether the answer is correct (use Google or any other method) and check the retrieved documents
#
# For each question, answer and context triple, record the following
#
# - How accurate is the answer (1-5, 5 best)?
# - How relevant is the retrieved context (1-5, 5 best)?
# - How grounded is the answer in the retrieved context (instead of relying on the LLM's internal knowledge) (1-5, 5 best)?
#
# **--- ADD YOUR SOLUTION HERE (20 points) ---**
#
# Question 1:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 4
#
# Question 2:
# - Accuracy (1 - 5): 4
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 3
#
# Question 3:
# - Accuracy (1 - 5): 3
# - Relevance (1 - 5): 1
# - Grounded in context without relying on LLM (1 - 5): 4
#
# Question 4:
# - Accuracy (1 - 5): 5
# - Relevance (1 - 5): 2
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 5:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 1
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 6:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 1
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 7:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 2
# - Grounded in context without relying on LLM (1 - 5): 4
#
# Question 8:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 9:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 10:
# - Accuracy (1 - 5): 2
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 4
#
# Question 11:
# - Accuracy (1 - 5): 5
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 12:
# - Accuracy (1 - 5): 3
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 4
#
# Question 13:
# - Accuracy (1 - 5): 4
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 14:
# - Accuracy (1 - 5): 4
# - Relevance (1 - 5): 3
# - Grounded in context without relying on LLM (1 - 5): 2
#
# Question 15:
# - Accuracy (1 - 5): 1
# - Relevance (1 - 5): 3
# - Grounded in context without relying on LLM (1 - 5): 2
#
# Question 16:
# - Accuracy (1 - 5): 5
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 17:
# - Accuracy (1 - 5): 3
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 18:
# - Accuracy (1 - 5): 5
# - Relevance (1 - 5): 5
# - Grounded in context without relying on LLM (1 - 5): 5
#
# Question 19:
# - Accuracy (1 - 5): 2
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 3
#
# Question 20:
# - Accuracy (1 - 5): 5
# - Relevance (1 - 5): 4
# - Grounded in context without relying on LLM (1 - 5): 4
# ------------------------------

# %% [markdown]
# You can try improve the chatbot by going back to previous steps in the notebook and change things until the submission deadline. For example, you can add more data sources, change the embedding models, change the data pre-processing, etc.

# %% [markdown]
# # End
#
# This concludes assignment 3.
#
# Please submit this notebook with your answers and the generated output cells as a **Jupyter notebook file** via github.
#
#
# Every group member should do the following submission steps:
# 1. Create a private github repository **sutd_5055mlop** under your github user.
# 2. Add your instructors as collaborator: ddahlmeier and lucainiaoge
# 3. Save your submission as assignment_03_GROUP_NAME.ipynb where GROUP_NAME is the name of the group you have registered.
# 4. Push the submission files to your repo
# 5. Submit the link to the repo via eDimensions
#
#
#
# **Assignment due 6 April 2025 11:59pm**
